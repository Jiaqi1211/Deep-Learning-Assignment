# %% [markdown]
# # Deep learning programming I-A: Regression
# Felix Wiewel, Institute of Signal Processing and System Theory, University of Stuttgart, 24.04.2020
#
# ## Introduction
# This programming exercise is the first of a series of exercises, which are intended as a supplement to the theoretical part of the Deep Learning course offered by the ISS. The goal is to introduce you to basic tasks and applications of methods you have encountered in the lecture. After completing the exercise you should be familiar with the basic ideas and one, possibly simple, way of solving the respective task. It is worth mentioning that most of the tasks can be solved in many different, not necessarily deep learning based, ways and the solution presented here is just one of them.
#
# ## Regression
#
# In this exercise we consider the problem of regression, where we are interested in modeling a functional dependence between different variables with, possibly noisy, observations of input-output pairs. Mathematically such a dependence can be formulated as
#
# $\mathbf{y}=f(\mathbf{x})+\boldsymbol{\epsilon}$,
#
# where $\mathbf{y}\in\mathbb{R}^{M}$ and $\mathbf{x}\in\mathbb{R}^{N}$ are the input and output observations, $f:\mathbb{R}^{N}\rightarrow\mathbb{R}^{M}$ is the function mapping inputs to outputs and $\boldsymbol{\epsilon}\in\mathbb{R}^{M}$ is a random vector, which models noise in our observations. Note that this assumes additive noise that only acts on the output and not on the input variable, which might not be true in all practical applications but is a reasonable approximation. For regression we are now interested in estimating the functional relationship $f$ between the inputs and outputs. This can be done in many different ways, not just with neural networks, but for this exercise we focus on approximating this relationship with a neural network $g_{\boldsymbol{\theta}}:\mathbb{R}^{N}\rightarrow\mathbb{R}^{M}$ with parameter vector $\boldsymbol{\theta}$. The task is now to choose the parameters of the neural network in a way that results in a "good" approximation of $f$ with $g_{\boldsymbol{\theta}}$.
#
# In order to quantify how "good" our neural network can approximate $f$, we adopt a probabilistic view. For this we make the assumption that the noise $\boldsymbol{\epsilon}$ is a random vector drawn from a known dustribution, which enables us to derive a suitable cost function for training our neural network and also for quantifying a "good" approximation.
#
# ### Mathematical formulation
# If we assume that the noise $\boldsymbol{\epsilon}$ is drawn from a gaussian distribution, e.g. $\boldsymbol{\epsilon}\sim\mathcal{N}(\mathbf{0},\sigma^{2}\mathbf{I})$, we can use
#
# $\mathbf{y}=g_{\boldsymbol{\theta}}(\mathbf{x})+\boldsymbol{\epsilon}\Rightarrow \mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})=\boldsymbol{\epsilon}$
#
# to derive a log likelihood. Since the probability density function (pdf) of a multivariate normal distribution is given by
#
# $p(\mathbf{x})=\dfrac{1}{\sqrt{(2\pi)^{D}\vert\mathbf{C}\vert}}\mathrm{e}^{-\dfrac{1}{2}(\mathbf{x}-\boldsymbol{\mu})\mathbf{C}^{-1}(\mathbf{x}-\boldsymbol{\mu})^{T}}$,
#
# we get
#
# $\ln{p(\boldsymbol{\epsilon})}=\ln{\dfrac{1}{\sqrt{(2\pi)^{M}\sigma^{2}}}\mathrm{e}^{-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\epsilon}\Vert_{2}^{2}}}=-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\epsilon}\Vert_{2}^{2}-\dfrac{1}{2}\ln{(2\pi)^{M}\sigma^{2}}$.
#
# Replacing $\boldsymbol{\epsilon}$ by $\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})$ yields the log likelihood for one particular input-output pair:
#
# $\mathcal{L}(\mathbf{x},\mathbf{y},\boldsymbol{\theta})=\ln {p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})}=-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}-\dfrac{1}{2}\ln{(2\pi)^{M}\sigma^{2}}$
#
# This log likelihood measures how likely the input-output pair is and we can use it to train our neural network. For this we maximize the expected log likelihood over all input-output pairs under the assumption that the noise is idependent and identically distributed (i.i.d.) over all input-output pairs. This corresponds to finding the parameters $\boldsymbol{\theta}^{\star}$ of our neural network, which maximize the the expected probability for observing the corresponding input-output pairs. Mathematically the optimal parameters for our neural network are given by
#
# $\boldsymbol{\theta}^{\star}=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[\mathcal{L}(\mathbf{x},\mathbf{y},\boldsymbol{\theta})\right]=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[-\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}\right]\approx\arg\min_{\boldsymbol{\theta}}\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where all terms, which are independent of $\boldsymbol{\theta}$, are ignored and the expectation operator is approximated by the mean over all $N_{D}$ input-output pairs. In other words we are maximizing the log likelihood by minimizing the mean squared error loss over all input-output pairs in our dataset, hence this approach is called Maximum Likelihood (ML) estimation. For solving this optimization problem and obtaining the optimal network parameters, stochastic gradient descent (SGD) or one of it's many variants is typically used.
#
# It is worth noting, that choosing different distributions for the noise $\boldsymbol{\epsilon}$ leads to different log likelihoods and therefore different cost functions for training the neural network. Another commonly used distribution for modelling the noise in regression tasks is the laplace distribution. Deriving the log likelihood and the corresponding costfunction leads to the mean absolute error, which is given by the $l_{1}$-norm of the difference between observations predictions of the neural network. This cost function is considered more robust against outliers since these have less influence on the averall loss compared to the mean squared error.
#
# ###  Implementation
#
# In the following we consider a simple regression task, implement a neural network and train it based on the mathematical fomrulation above. For this we first need to create a set of input-output pairs, which then needs to be partitioned into a training, validation and test set. We also define some constants to be used for partitioning the data and the hyperparameters for our neural network.
#
# But before we can start, we need to import the necessary packages tensorflow, numpy and matplotlib.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Next we define our constants and set the random seeds of tensorflow and numpy in order to get reproducable results.

# %%
N_train_samples = 600
N_validation_samples = 100
N_test_samples = 100
N_samples = N_train_samples + N_validation_samples + N_test_samples
noise_sig = 0.1
N_epochs = 150
batch_size = 8
learning_rate = 0.01

tf.random.set_seed(0)
np.random.seed(0)

# %% [markdown]
# We create $600$ training samples, $100$ validation samples to optimize our hyperparameters and $100$ test samples, which are used to check if our model can generalize to unseen data. Furthermore we set the level of noise added to the observations. For training the model we plan to train it for $150$ epochs with a batch size of $8$ and a learning rate of $0.01$. Next we create the actual input-output pairs $\mathbf{x},\mathbf{y}$ for which we want to learn the regression model and plot them. In this simple example we choose scalar inputs as well as output but in general $\mathbf{x}$ and $\mathbf{y}$ can be vectors.

# %%
x = np.linspace(0.0, 3.0, N_samples, dtype=np.float32)
y = np.expand_dims(np.sin(1.0+x*x) + noise_sig*np.random.randn(N_samples).astype(np.float32), axis=-1)
y_true = np.sin(1.0+x*x)

plt.plot(x, y)
plt.plot(x, y_true)
plt.legend(["Observation", "Ground truth"])
plt.show()
#x.shape
#y.shape

# %% [markdown]
# With the input-output pairs created, your first task is now to partition the data in the training, validation and test sets. Keep in mind that we have created the data in a structured way, i.e. the input-output pairs are ordered. This means you need to shuffle the data before partitioning it.

# %%
""" Shuffle and partition the data set accordingly. you can use the predefined constants "N_train_samples", "N_validation_samples" and "N_test_samples". Use the variable names that are already in the below code 
to store the final shuffled and partitioned data. Hint: Shuffle the data and the labels in such a way that the pairing between an image and it's label is preserved."""
# Shuffle the data
rnd_idx = np.random.permutation(x.shape[0])
# Partition the data
x_train = x[rnd_idx[:N_train_samples]]
y_train = y[rnd_idx[:N_train_samples]]
x_validation = x[rnd_idx[N_train_samples:(N_train_samples+N_validation_samples)]]
y_validation = y[rnd_idx[N_train_samples:(N_train_samples+N_validation_samples)]]
x_test = x[rnd_idx[(N_train_samples+N_validation_samples):(N_samples)]]
y_test = y[rnd_idx[(N_train_samples+N_validation_samples):(N_samples)]]
#print(x_train.shape)
#print(y_train.shape)

# %% [markdown]
# In order to feed the data to our model, we will use the Dataset class provided by Tensorflow. This class is simple to use and provides all the functionality we need for shuffling, batching and feeding the data to our model. It is also tightly integrated into the Tensorflow framework, which makes it very performant. Performance is not an aspect we need to worry about in this exercise, but it is important in more demanding applications.
#
# In this exercise we instantiate a separate Dataset object for the training, validation and test data sets, where we shuffle and repeat just the training data set. Shuffling the validation and test data sets is not necessary, since we only evaluate the loss on those data sets and do not perform SGD on it. Please fill in the missing part of the code.

# %%
""" Create three tensorflow Dataset objects that can be used to feed the training test and validation data to a neural network. Hint: For the training data set use shuffling, batching with the size according to
the predefined constant "batch_size" and repeat the data set indefinetly. For the validation and test data sets no shuffling or batching is needed."""
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))

train_ds =  train_dataset.shuffle(100).batch(batch_size).repeat()
validation_ds = tf.data.Dataset.from_tensor_slices((x_validation, y_validation))
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))
#print(train_ds)

# %% [markdown]
# In this exercise we will create a a simple neural network with two hidden layers containing $10$ neurons. For creating a model and keeping track of its weights a class called MyModel is used. When initializing an instance of this class the necessary variables are created and stored in a list called "trainable_variables". This makes it easy to get all trainable variables of the model. We also override the \__call__ method of this class in order to implement the forward pass of the neural network. This method should accept the inputs to the neural network and should return the result of the forward pass as an output. Please fill in the missing part of the code and select suitable activation functions for the different layers.

# %%
""" Implement a neural network with two hidden dense layers containing 10 neurons each. As an activation function use the tangens hyperbolicus (tf.nn.tanh()). Since we are not using Keras, we need to create and 
manage all the variables that we need ourselves. The varaibles are created in the constructor of our model class. Since we want to be able to just call the class with some inputs in order to make a prediction, 
we implement a __call__ method which computes the forward pass and returns the output of the network."""

class MyModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(tf.random.truncated_normal([1,10]))
        self.b0 = tf.Variable(tf.zeros([10]))
        self.W1 = tf.Variable(tf.random.truncated_normal([10,10]))
        self.b1 = tf.Variable(tf.zeros([10]))
        self.W2 = tf.Variable(tf.random.truncated_normal([10,1]))
        self.b2 = tf.Variable(tf.zeros([1]))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh(tf.matmul(output,self.W0) + self.b0)
        output = tf.nn.tanh(tf.matmul(output,self.W1) + self.b1)
        output = tf.nn.tanh(tf.matmul(output,self.W2) + self.b2)
        return output

# %% [markdown]
# Now after the model class is defined we can instantiate a MyModel object by running

# %%
mdl = MyModel()

# %% [markdown]
# We can now use the model to make predictions by calling it. In the following we predict on the inputs an plot the result.

# %%
""" We want to plot a prediction on the complete data set with a model before training. For this make a prediction on the variable "x". """

y_pred = mdl(x)# Compute a prediction on the variable "x"
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Since we have initialized the variables of the neural network randomly, it's prediction is also random. In order to fit the model we need to minimize the expected mean squared error over all input-ouput pairs in our training data set. For this we need to create a function, that performs a training step when provided with the model, an optimizer and a batch of input-ouput pairs.

# %%
""" For training we need to implement a function that executes one training step. Fill in the missing code pieces for this function."""

def train_step(model, optimizer, x, y):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model(x)# Compute a prediction with "model" on the input "x"
        loss_val = tf.reduce_mean(tf.square(y -  y_pred)) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
    grads = tape.gradient(loss_val, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# This function uses the GradientTape to record the operations for which gradients have to be calculated. In our case this is the forward pass through our model and the computation of the loss function. After these operations are recoded we can get their gradients and apply these through the use of an optimizer. Finally we return the loss value in order to print it.
#
# With the training step function defined we now need to choose a suitable optimizer. Tensorflow offers a wide variety of optimizers but in this exercise we will use the RMSprop optimizer.

# %%
opt = tf.optimizers.RMSprop(learning_rate)

# %% [markdown]
# We now have everything we need to start training the model. For this we repeatedly sample a batch of input-output pairs from our training data set and use the train_step function to minimize the loss function over this batch. We repeat this until we have iterated over the complete training data set once. After this we compute the loss on the validation data set, print it and repeat with another epoch until we have reached $N\_epochs$ epochs.

# %%
""" We can now use the train_step function to perform the training. Fill in the missing code parts."""

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_ds:
    train_loss += train_step(mdl,opt,x_t,y_t)# Perform a training step with the model "mdl" and the optimizer "opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
    if(train_iters == N_train_samples//batch_size): # An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = mdl(x_v) # Compute a prediction with "mdl" on the input "x_v"
            validation_loss = tf.reduce_mean(tf.square(y_v -  y_pred)) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 0.34386 Validation loss: 0.026815
# Epoch: 1 Train loss: 0.2598 Validation loss: 0.026147
# Epoch: 2 Train loss: 0.20201 Validation loss: 0.021917
# Epoch: 3 Train loss: 0.15998 Validation loss: 0.0068667
# Epoch: 4 Train loss: 0.13783 Validation loss: 0.0019844
# Epoch: 5 Train loss: 0.11701 Validation loss: 0.00049157
# Epoch: 6 Train loss: 0.11391 Validation loss: 0.0036088
# Epoch: 7 Train loss: 0.10532 Validation loss: 0.010107
# Epoch: 8 Train loss: 0.10224 Validation loss: 0.014889
# Epoch: 9 Train loss: 0.0961 Validation loss: 0.0076105
# Epoch: 10 Train loss: 0.087738 Validation loss: 0.0017774
# Epoch: 11 Train loss: 0.085212 Validation loss: 0.011037
# Epoch: 12 Train loss: 0.080499 Validation loss: 0.0065692
# Epoch: 13 Train loss: 0.080933 Validation loss: 5.5143e-06
# Epoch: 14 Train loss: 0.072279 Validation loss: 0.00016789
# Epoch: 15 Train loss: 0.065119 Validation loss: 0.0017766
# Epoch: 16 Train loss: 0.058751 Validation loss: 0.0042206
# Epoch: 17 Train loss: 0.052726 Validation loss: 0.000758
# Epoch: 18 Train loss: 0.048672 Validation loss: 0.0067669
# Epoch: 19 Train loss: 0.045946 Validation loss: 0.003588
# Epoch: 20 Train loss: 0.042931 Validation loss: 0.0029196
# Epoch: 21 Train loss: 0.04125 Validation loss: 0.0044195
# Epoch: 22 Train loss: 0.036961 Validation loss: 0.0031038
# Epoch: 23 Train loss: 0.035148 Validation loss: 0.0054064
# Epoch: 24 Train loss: 0.034444 Validation loss: 0.00079329
# Epoch: 25 Train loss: 0.034703 Validation loss: 0.0047481
# Epoch: 26 Train loss: 0.034788 Validation loss: 0.0024091
# Epoch: 27 Train loss: 0.032991 Validation loss: 0.0032207
# Epoch: 28 Train loss: 0.031997 Validation loss: 0.0022708
# Epoch: 29 Train loss: 0.03031 Validation loss: 0.002555
# Epoch: 30 Train loss: 0.033874 Validation loss: 0.0014113
# Epoch: 31 Train loss: 0.026859 Validation loss: 0.0014856
# Epoch: 32 Train loss: 0.029351 Validation loss: 0.0021631
# Epoch: 33 Train loss: 0.030462 Validation loss: 0.0017621
# Epoch: 34 Train loss: 0.027823 Validation loss: 0.0023967
# Epoch: 35 Train loss: 0.026729 Validation loss: 0.00099574
# Epoch: 36 Train loss: 0.026582 Validation loss: 0.00060804
# Epoch: 37 Train loss: 0.0283 Validation loss: 0.0032475
# Epoch: 38 Train loss: 0.023272 Validation loss: 0.0033734
# Epoch: 39 Train loss: 0.027274 Validation loss: 0.0016436
# Epoch: 40 Train loss: 0.024997 Validation loss: 0.00049532
# Epoch: 41 Train loss: 0.028331 Validation loss: 0.0028962
# Epoch: 42 Train loss: 0.022399 Validation loss: 0.0011824
# Epoch: 43 Train loss: 0.026546 Validation loss: 0.0037807
# Epoch: 44 Train loss: 0.025513 Validation loss: 0.0010909
# Epoch: 45 Train loss: 0.024324 Validation loss: 0.0015937
# Epoch: 46 Train loss: 0.024775 Validation loss: 0.00031678
# Epoch: 47 Train loss: 0.025301 Validation loss: 0.0027935
# Epoch: 48 Train loss: 0.022281 Validation loss: 0.0024149
# Epoch: 49 Train loss: 0.023978 Validation loss: 0.00060338
# Epoch: 50 Train loss: 0.021046 Validation loss: 0.002328
# Epoch: 51 Train loss: 0.024321 Validation loss: 0.0010704
# Epoch: 52 Train loss: 0.021006 Validation loss: 0.002751
# Epoch: 53 Train loss: 0.022701 Validation loss: 0.0042404
# Epoch: 54 Train loss: 0.024282 Validation loss: 0.0018586
# Epoch: 55 Train loss: 0.022465 Validation loss: 0.0015225
# Epoch: 56 Train loss: 0.020496 Validation loss: 0.0031926
# Epoch: 57 Train loss: 0.023778 Validation loss: 0.0020538
# Epoch: 58 Train loss: 0.024734 Validation loss: 0.0027926
# Epoch: 59 Train loss: 0.021365 Validation loss: 0.0026945
# Epoch: 60 Train loss: 0.021178 Validation loss: 0.00030908
# Epoch: 61 Train loss: 0.022266 Validation loss: 0.0059962
# Epoch: 62 Train loss: 0.021836 Validation loss: 0.0035819
# Epoch: 63 Train loss: 0.024223 Validation loss: 0.0033019
# Epoch: 64 Train loss: 0.023254 Validation loss: 0.00034249
# Epoch: 65 Train loss: 0.019157 Validation loss: 0.0040136
# Epoch: 66 Train loss: 0.023542 Validation loss: 0.0017422
# Epoch: 67 Train loss: 0.021169 Validation loss: 0.003613
# Epoch: 68 Train loss: 0.023062 Validation loss: 0.0041649
# Epoch: 69 Train loss: 0.021637 Validation loss: 0.00241
# Epoch: 70 Train loss: 0.020241 Validation loss: 0.0045487
# Epoch: 71 Train loss: 0.02223 Validation loss: 0.0017541
# Epoch: 72 Train loss: 0.021264 Validation loss: 0.0039476
# Epoch: 73 Train loss: 0.020932 Validation loss: 0.0028197
# Epoch: 74 Train loss: 0.020167 Validation loss: 0.00037954
# Epoch: 75 Train loss: 0.021461 Validation loss: 0.001611
# Epoch: 76 Train loss: 0.020774 Validation loss: 0.00342
# Epoch: 77 Train loss: 0.021651 Validation loss: 0.0023414
# Epoch: 78 Train loss: 0.019752 Validation loss: 0.001243
# Epoch: 79 Train loss: 0.019745 Validation loss: 0.0036858
# Epoch: 80 Train loss: 0.022337 Validation loss: 0.0029269
# Epoch: 81 Train loss: 0.021503 Validation loss: 0.00091728
# Epoch: 82 Train loss: 0.019001 Validation loss: 0.0022791
# Epoch: 83 Train loss: 0.021782 Validation loss: 0.00087259
# Epoch: 84 Train loss: 0.020607 Validation loss: 0.0031454
# Epoch: 85 Train loss: 0.020347 Validation loss: 0.0048979
# Epoch: 86 Train loss: 0.021561 Validation loss: 0.0019553
# Epoch: 87 Train loss: 0.020114 Validation loss: 0.0026235
# Epoch: 88 Train loss: 0.023469 Validation loss: 0.0016841
# Epoch: 89 Train loss: 0.018888 Validation loss: 0.00085196
# Epoch: 90 Train loss: 0.021492 Validation loss: 0.00065637
# Epoch: 91 Train loss: 0.0189 Validation loss: 0.0034415
# Epoch: 92 Train loss: 0.021729 Validation loss: 0.003179
# Epoch: 93 Train loss: 0.020257 Validation loss: 0.00051094
# Epoch: 94 Train loss: 0.021027 Validation loss: 0.00013628
# Epoch: 95 Train loss: 0.020854 Validation loss: 0.0030649
# Epoch: 96 Train loss: 0.021915 Validation loss: 0.0026902
# Epoch: 97 Train loss: 0.020609 Validation loss: 0.0010807
# Epoch: 98 Train loss: 0.021048 Validation loss: 0.0029174
# Epoch: 99 Train loss: 0.019797 Validation loss: 0.0022068
# Epoch: 100 Train loss: 0.020518 Validation loss: 0.0030855
# Epoch: 101 Train loss: 0.020928 Validation loss: 0.0026711
# Epoch: 102 Train loss: 0.018599 Validation loss: 0.0018924
# Epoch: 103 Train loss: 0.021099 Validation loss: 0.0032261
# Epoch: 104 Train loss: 0.02015 Validation loss: 0.002343
# Epoch: 105 Train loss: 0.020847 Validation loss: 0.0036532
# Epoch: 106 Train loss: 0.021336 Validation loss: 0.00016616
# Epoch: 107 Train loss: 0.01965 Validation loss: 0.0047819
# Epoch: 108 Train loss: 0.02264 Validation loss: 0.0035311
# Epoch: 109 Train loss: 0.018035 Validation loss: 0.0018148
# Epoch: 110 Train loss: 0.019042 Validation loss: 0.0025145
# Epoch: 111 Train loss: 0.020428 Validation loss: 0.0038889
# Epoch: 112 Train loss: 0.020663 Validation loss: 0.0012969
# Epoch: 113 Train loss: 0.01904 Validation loss: 0.0036853
# Epoch: 114 Train loss: 0.021013 Validation loss: 0.0017703
# Epoch: 115 Train loss: 0.019456 Validation loss: 0.0019739
# Epoch: 116 Train loss: 0.018864 Validation loss: 0.0035484
# Epoch: 117 Train loss: 0.020771 Validation loss: 0.0035966
# Epoch: 118 Train loss: 0.019312 Validation loss: 0.0042661
# Epoch: 119 Train loss: 0.020284 Validation loss: 0.0035607
# Epoch: 120 Train loss: 0.018344 Validation loss: 0.003669
# Epoch: 121 Train loss: 0.020119 Validation loss: 0.00066942
# Epoch: 122 Train loss: 0.019159 Validation loss: 0.0022644
# Epoch: 123 Train loss: 0.020229 Validation loss: 0.0034309
# Epoch: 124 Train loss: 0.021096 Validation loss: 0.0022111
# Epoch: 125 Train loss: 0.018648 Validation loss: 0.0021534
# Epoch: 126 Train loss: 0.01878 Validation loss: 0.0023573
# Epoch: 127 Train loss: 0.020154 Validation loss: 0.0041385
# Epoch: 128 Train loss: 0.019372 Validation loss: 0.0020605
# Epoch: 129 Train loss: 0.019276 Validation loss: 0.002232
# Epoch: 130 Train loss: 0.019943 Validation loss: 0.0055683
# Epoch: 131 Train loss: 0.021137 Validation loss: 0.0027186
# Epoch: 132 Train loss: 0.019324 Validation loss: 0.0024825
# Epoch: 133 Train loss: 0.020286 Validation loss: 0.0007462
# Epoch: 134 Train loss: 0.020296 Validation loss: 0.0022721
# Epoch: 135 Train loss: 0.017911 Validation loss: 0.0040537
# Epoch: 136 Train loss: 0.020632 Validation loss: 0.0018214
# Epoch: 137 Train loss: 0.02076 Validation loss: 0.0027777
# Epoch: 138 Train loss: 0.019472 Validation loss: 0.0026001
# Epoch: 139 Train loss: 0.02087 Validation loss: 0.0027156
# Epoch: 140 Train loss: 0.021139 Validation loss: 0.00154
# Epoch: 141 Train loss: 0.020814 Validation loss: 0.0028541
# Epoch: 142 Train loss: 0.021063 Validation loss: 0.0038954
# Epoch: 143 Train loss: 0.01852 Validation loss: 0.0014432
# Epoch: 144 Train loss: 0.019188 Validation loss: 0.0019293
# Epoch: 145 Train loss: 0.018686 Validation loss: 0.0017538
# Epoch: 146 Train loss: 0.019875 Validation loss: 0.0030307
# Epoch: 147 Train loss: 0.021346 Validation loss: 0.0023787
# Epoch: 148 Train loss: 0.019047 Validation loss: 0.0012794
# Epoch: 149 Train loss: 0.019404 Validation loss: 0.0034107

# %% [markdown]
# After completion of the training process we use the test data set to test the models generalization to unseen data.

# %%
for x_t, y_t in test_ds:
    y_pred = mdl(x_t) # Compute a prediction with "mdl" on the input "x_t"
    test_loss = tf.reduce_mean(tf.square(y_t -  y_pred))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_t"
print("Test loss: {:.5}".format(test_loss))
# Out:
# Test loss: 0.0077381

# %% [markdown]
# After we have verified that our model achieves a similar loss on the test as on the validation and training data set, we can conclude that our model is not overfitting or underfitting and generalizes to unseen data. We can now predict on the inputs again and plot the results.

# %%
""" Now we want to plot the prediction after training. Predict on the variable "x" again. """

y_pred = mdl(x) # Compute a prediction on the variable "x"
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Now our model has learned to approximate the function mapping from the input to the output. The capability of neural networks to learn from input-ouput pairs alone and approximate an arbitrary function, see universal approximation theorem, can be very useful if the mapping between the input and output is too complex to be captured with model based approaches. But learning from input-ouput pairs alone implies that the model will only be able to make accurate predictions over input ranges it has seen during training. In order to demonstrate this we will predict on an interval that exeeds the $\left[0,3\right]$ interval the model was trained on, i.e. we will predict on the interval $\left[-2,5\right]$.

# %%
x_generalize = np.linspace(-2.0, 5.0, N_samples, dtype=np.float32)
y_generalize = np.sin(1.0+x_generalize*x_generalize) + noise_sig*np.random.randn(N_samples).astype(np.float32)
y_truey_generalize = np.sin(1.0+x_generalize*x_generalize)
y_pred = mdl(x_generalize)
plt.plot(x_generalize, y_generalize)
plt.plot(x_generalize, y_truey_generalize)
plt.plot(x_generalize, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# As expected, the model is able to make farely accurate predictions on the interval it was trained on but makes unreliable predictions outside this interval.
#
# ### Regularization
# In this section we will explore the concept of regularization. As there is no theorem that can be used to determine the required size and structure of a neural network given a certain task, one has to find a suitable neural architecture by trial and error. This can result in choosing a architecture with a capacity that is higher than required for solving the given task and hence overfitting might occur. A common way to prevent large neural networks networks from overfitting is to employ some sort of regularization, e.g. weight norm penalty, dropout, early stopping and data augmentation. In this section we will focus on weight norm penalty as a regularization and derive a probabilistic interpretation for some of those.
#
# We start by restating the conditional probability of the output $\mathbf{y}$ given the input $\mathbf{x}$ and the networks parameters $\boldsymbol{\theta}$
#
# $p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})=\dfrac{1}{\sqrt{(2\pi)^{M}\sigma^{2}}}\mathrm{e}^{-\dfrac{1}{2\sigma^{2}}\Vert\boldsymbol{\mathbf{y}-g_{\boldsymbol{\theta}}(\mathbf{x})}\Vert_{2}^{2}}$,
#
# which we used to derive the log likelihood. If we have some prior knowledge about the parameters of the neural network, which is given by a pdf $p(\boldsymbol{\theta})$ over the weights, we can use Bayes theorem to derive a posterior distribution
#
# $p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})=\dfrac{p(\boldsymbol{\theta},\mathbf{y}\vert\mathbf{x})}{p(\mathbf{y})}=\dfrac{p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})p(\boldsymbol{\theta})}{p(\mathbf{y})}$
#
# where $p(\boldsymbol{\theta})$ is the  prior over the networks parameters. Similar to the derivation at the beginning of the exercise, we can use this posterior distribution to derive a cost function for training the neural network. In this case, however, we are not maximizing the log likelihood but the posterior distribution over the weights, hence this approach is called Maximum A Posteori (MAP) estimation of the parameters. Mathematically we can formulate this as
#
# $\boldsymbol{\theta}^{\star}=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})\right]=\arg\max_{\boldsymbol{\theta}}\mathbb{E}\left[\ln{p(\boldsymbol{\theta}\vert\mathbf{x},\mathbf{y})}\right]=\arg\max_{\boldsymbol{\theta}}\ln{p(\boldsymbol{\theta})}+\mathbb{E}\left[\ln{p(\mathbf{y}\vert\mathbf{x},\boldsymbol{\theta})}\right]$,
#
# where we used the fact that applying a strictly increasing function, e.g. $\ln{}$, does not change the position of the maximum of a cost function, ignored $p(\mathbf{y})$, since it is independent of the network parameters and dropped the expectation operator for $\ln{p(\boldsymbol{\theta})}$, since it is not depending on the random variable $\mathbf{x}$. Comparing the MAP estimate of the parameters with the ML estimate we derived above, shows that the only difference is the addition of $\ln{p(\boldsymbol{\theta})}$. This term is the regularization, i.e. the weight norm penalty. Depending on the distribution over $\boldsymbol{\theta}$ it can have different forms. If we choose a standard normal distribution, i.e. $\boldsymbol{\theta\sim\mathcal{N}(\mathbf{0},\mathbf{I})}$,  we get
#
# $\boldsymbol{\theta}^{\star}=\arg\min_{\boldsymbol{\theta}}\lambda\Vert\boldsymbol{\theta}\Vert_{2}^{2}+\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where we have made the same simplifications as for the ML estimation and also introduced the parameter $\lambda=\sigma^{2}$, which is used to control the strength of the regularization. This form of regularization is commonly known as $l_{2}$-norm or weight decay regularization. Choosing a prior where the weights follow an i.i.d laplacian distribution, i.e. $p(\boldsymbol{\theta})=\prod_{j}\dfrac{1}{2}\mathrm{e}^{\vert\theta_{j}\vert}$, leads to
#
# $\boldsymbol{\theta}^{\star}=\arg\min_{\boldsymbol{\theta}}\lambda\Vert\boldsymbol{\theta}\Vert_{1}+\dfrac{1}{N_{D}}\sum_{i=1}^{N_{D}}\Vert\boldsymbol{\mathbf{y}_{i}-g_{\boldsymbol{\theta}}(\mathbf{x}_{i})}\Vert_{2}^{2}$,
#
# where the strength of the regularization is again controlled by $\lambda=\sigma^{2}$. This type of regularization is known as  $l_{1}$-norm and it has the property to induce sparsity in the parameters of the network.
#
# With this theoretical background on regularization we can now implement it and observe it's effects on the regression problem covered in this exercise. For this we will define a model with a high capacity and train it for a extended time to provoke overfitting. For this, we will increase the number of hidden neurons in both hidden layers to $100$ and $50$.

# %%
""" Implement a bigger model with again two hidden layers contatining 100 and 50 neurons. As an activation use the tangens hyperbolicus function where it is appropiate. """

class MyBigModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(tf.random.truncated_normal([1,100]))
        self.b0 = tf.Variable(tf.zeros([100]))
        self.W1 = tf.Variable(tf.random.truncated_normal([100,50]))
        self.b1 = tf.Variable(tf.zeros([50]))
        self.W2 = tf.Variable(tf.random.truncated_normal([50,1]))
        self.b2 = tf.Variable(tf.zeros([1]))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh(tf.matmul(output,self.W0) + self.b0)
        output = tf.nn.tanh(tf.matmul(output,self.W1) + self.b1)
        output = tf.nn.tanh(tf.matmul(output,self.W2) + self.b2)
        return output

# %% [markdown]
# After creating one instance of this class we can again train it on our data set. We will also create a new optimizer for training this bigger model, since some optimizers adapt the learning rates for individual parameters during a training process and we do not want to train our bigger model with learning rates adopted from an earlier training run.

# %%
big_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

# %% [markdown]
# Now we are ready to train this bigger model using the same training step and training loop. In order to provoke overfitting we also reduce the number of samples in the training data set a lot, increase the batch size and train for a more epochs.

# %%
""" Implement the training for the bigger model similar to the training of the small model before. """

N_train_samples_overfit = 30
N_epochs = 1000
batch_size = 30

sel_idx = np.arange(0, N_train_samples)
sel_idx = np.random.choice(sel_idx, N_train_samples_overfit)
x_train_overfit = x_train[sel_idx]
y_train_overfit = y_train[sel_idx]

train_overfit_ds = tf.data.Dataset.from_tensor_slices((x_train_overfit, y_train_overfit)).shuffle(N_train_samples_overfit).batch(batch_size).repeat()

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    train_loss += train_step(big_mdl,big_opt,x_t,y_t)# Perform a training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
    if (train_iters == N_train_samples//batch_size):# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = big_mdl(x_v)# Compute a prediction with "big_mdl" on the input "x_v"
            validation_loss = tf.reduce_mean(tf.square(y_v-y_pred))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 1.1042 Validation loss: 0.028091
# Epoch: 1 Train loss: 0.77365 Validation loss: 0.014186
# Epoch: 2 Train loss: 0.31485 Validation loss: 0.031376
# Epoch: 3 Train loss: 0.14327 Validation loss: 0.033038
# Epoch: 4 Train loss: 0.1007 Validation loss: 0.033524
# Epoch: 5 Train loss: 0.088085 Validation loss: 0.033775
# Epoch: 6 Train loss: 0.079898 Validation loss: 0.033908
# Epoch: 7 Train loss: 0.073438 Validation loss: 0.033972
# Epoch: 8 Train loss: 0.068234 Validation loss: 0.033996
# Epoch: 9 Train loss: 0.06402 Validation loss: 0.033997
# Epoch: 10 Train loss: 0.060577 Validation loss: 0.033983
# Epoch: 11 Train loss: 0.057726 Validation loss: 0.033958
# Epoch: 12 Train loss: 0.055332 Validation loss: 0.033922
# Epoch: 13 Train loss: 0.053297 Validation loss: 0.033875
# Epoch: 14 Train loss: 0.051544 Validation loss: 0.033815
# Epoch: 15 Train loss: 0.050018 Validation loss: 0.03374
# Epoch: 16 Train loss: 0.048675 Validation loss: 0.033645
# Epoch: 17 Train loss: 0.047481 Validation loss: 0.033523
# Epoch: 18 Train loss: 0.046407 Validation loss: 0.033367
# Epoch: 19 Train loss: 0.045431 Validation loss: 0.033162
# Epoch: 20 Train loss: 0.044532 Validation loss: 0.032886
# Epoch: 21 Train loss: 0.043694 Validation loss: 0.032502
# Epoch: 22 Train loss: 0.042901 Validation loss: 0.031945
# Epoch: 23 Train loss: 0.042136 Validation loss: 0.031083
# Epoch: 24 Train loss: 0.041376 Validation loss: 0.029637
# Epoch: 25 Train loss: 0.040586 Validation loss: 0.026988
# Epoch: 26 Train loss: 0.039735 Validation loss: 0.022376
# Epoch: 27 Train loss: 0.038936 Validation loss: 0.017903
# Epoch: 28 Train loss: 0.038314 Validation loss: 0.015571
# Epoch: 29 Train loss: 0.037755 Validation loss: 0.013756
# Epoch: 30 Train loss: 0.037218 Validation loss: 0.011861
# Epoch: 31 Train loss: 0.036702 Validation loss: 0.0098417
# Epoch: 32 Train loss: 0.036208 Validation loss: 0.0077673
# Epoch: 33 Train loss: 0.035737 Validation loss: 0.0057624
# Epoch: 34 Train loss: 0.035294 Validation loss: 0.0039865
# Epoch: 35 Train loss: 0.034886 Validation loss: 0.0025781
# Epoch: 36 Train loss: 0.034516 Validation loss: 0.0015885
# Epoch: 37 Train loss: 0.034185 Validation loss: 0.00096434
# Epoch: 38 Train loss: 0.033889 Validation loss: 0.00059782
# Epoch: 39 Train loss: 0.033622 Validation loss: 0.00038756
# Epoch: 40 Train loss: 0.033379 Validation loss: 0.00026466
# Epoch: 41 Train loss: 0.033155 Validation loss: 0.00018941
# Epoch: 42 Train loss: 0.032945 Validation loss: 0.00014053
# Epoch: 43 Train loss: 0.032749 Validation loss: 0.0001068
# Epoch: 44 Train loss: 0.032564 Validation loss: 8.2239e-05
# Epoch: 45 Train loss: 0.032389 Validation loss: 6.3448e-05
# Epoch: 46 Train loss: 0.032223 Validation loss: 4.8554e-05
# Epoch: 47 Train loss: 0.032066 Validation loss: 3.6396e-05
# Epoch: 48 Train loss: 0.031916 Validation loss: 2.6365e-05
# Epoch: 49 Train loss: 0.031773 Validation loss: 1.8053e-05
# Epoch: 50 Train loss: 0.031637 Validation loss: 1.1308e-05
# Epoch: 51 Train loss: 0.031506 Validation loss: 6.0707e-06
# Epoch: 52 Train loss: 0.031381 Validation loss: 2.3884e-06
# Epoch: 53 Train loss: 0.031262 Validation loss: 3.6213e-07
# Epoch: 54 Train loss: 0.031147 Validation loss: 1.3896e-07
# Epoch: 55 Train loss: 0.031036 Validation loss: 1.9015e-06
# Epoch: 56 Train loss: 0.03093 Validation loss: 5.8475e-06
# Epoch: 57 Train loss: 0.030828 Validation loss: 1.2193e-05
# Epoch: 58 Train loss: 0.030729 Validation loss: 2.1151e-05
# Epoch: 59 Train loss: 0.030634 Validation loss: 3.2937e-05
# Epoch: 60 Train loss: 0.030542 Validation loss: 4.7804e-05
# Epoch: 61 Train loss: 0.030454 Validation loss: 6.5887e-05
# Epoch: 62 Train loss: 0.030368 Validation loss: 8.741e-05
# Epoch: 63 Train loss: 0.030284 Validation loss: 0.00011256
# Epoch: 64 Train loss: 0.030204 Validation loss: 0.00014147
# Epoch: 65 Train loss: 0.030125 Validation loss: 0.00017431
# Epoch: 66 Train loss: 0.030049 Validation loss: 0.00021114
# Epoch: 67 Train loss: 0.029976 Validation loss: 0.00025213
# Epoch: 68 Train loss: 0.029904 Validation loss: 0.00029723
# Epoch: 69 Train loss: 0.029834 Validation loss: 0.00034658
# Epoch: 70 Train loss: 0.029766 Validation loss: 0.00040017
# Epoch: 71 Train loss: 0.029699 Validation loss: 0.00045803
# Epoch: 72 Train loss: 0.029634 Validation loss: 0.00052007
# Epoch: 73 Train loss: 0.029571 Validation loss: 0.00058628
# Epoch: 74 Train loss: 0.029509 Validation loss: 0.00065665
# Epoch: 75 Train loss: 0.029449 Validation loss: 0.00073112
# Epoch: 76 Train loss: 0.02939 Validation loss: 0.00080952
# Epoch: 77 Train loss: 0.029332 Validation loss: 0.00089189
# Epoch: 78 Train loss: 0.029275 Validation loss: 0.00097792
# Epoch: 79 Train loss: 0.02922 Validation loss: 0.0010677
# Epoch: 80 Train loss: 0.029165 Validation loss: 0.0011608
# Epoch: 81 Train loss: 0.029112 Validation loss: 0.0012575
# Epoch: 82 Train loss: 0.029059 Validation loss: 0.0013573
# Epoch: 83 Train loss: 0.029007 Validation loss: 0.0014601
# Epoch: 84 Train loss: 0.028957 Validation loss: 0.0015657
# Epoch: 85 Train loss: 0.028907 Validation loss: 0.0016742
# Epoch: 86 Train loss: 0.028858 Validation loss: 0.0017851
# Epoch: 87 Train loss: 0.028809 Validation loss: 0.0018983
# Epoch: 88 Train loss: 0.028761 Validation loss: 0.0020137
# Epoch: 89 Train loss: 0.028714 Validation loss: 0.0021312
# Epoch: 90 Train loss: 0.028668 Validation loss: 0.0022503
# Epoch: 91 Train loss: 0.028622 Validation loss: 0.0023713
# Epoch: 92 Train loss: 0.028577 Validation loss: 0.0024935
# Epoch: 93 Train loss: 0.028532 Validation loss: 0.002617
# Epoch: 94 Train loss: 0.028488 Validation loss: 0.0027417
# Epoch: 95 Train loss: 0.028444 Validation loss: 0.0028673
# Epoch: 96 Train loss: 0.0284 Validation loss: 0.0029934
# Epoch: 97 Train loss: 0.028357 Validation loss: 0.0031203
# Epoch: 98 Train loss: 0.028314 Validation loss: 0.0032474
# Epoch: 99 Train loss: 0.028272 Validation loss: 0.0033748
# Epoch: 100 Train loss: 0.02823 Validation loss: 0.0035023
# Epoch: 101 Train loss: 0.028188 Validation loss: 0.0036299
# Epoch: 102 Train loss: 0.028146 Validation loss: 0.0037573
# Epoch: 103 Train loss: 0.028105 Validation loss: 0.0038843
# Epoch: 104 Train loss: 0.028063 Validation loss: 0.0040107
# Epoch: 105 Train loss: 0.028022 Validation loss: 0.0041366
# Epoch: 106 Train loss: 0.027981 Validation loss: 0.0042614
# Epoch: 107 Train loss: 0.02794 Validation loss: 0.0043853
# Epoch: 108 Train loss: 0.0279 Validation loss: 0.0045084
# Epoch: 109 Train loss: 0.027859 Validation loss: 0.0046305
# Epoch: 110 Train loss: 0.027818 Validation loss: 0.0047509
# Epoch: 111 Train loss: 0.027777 Validation loss: 0.0048701
# Epoch: 112 Train loss: 0.027737 Validation loss: 0.0049876
# Epoch: 113 Train loss: 0.027696 Validation loss: 0.0051035
# Epoch: 114 Train loss: 0.027655 Validation loss: 0.0052177
# Epoch: 115 Train loss: 0.027614 Validation loss: 0.0053302
# Epoch: 116 Train loss: 0.027573 Validation loss: 0.0054408
# Epoch: 117 Train loss: 0.027533 Validation loss: 0.0055491
# Epoch: 118 Train loss: 0.027492 Validation loss: 0.0056556
# Epoch: 119 Train loss: 0.027451 Validation loss: 0.0057596
# Epoch: 120 Train loss: 0.02741 Validation loss: 0.0058615
# Epoch: 121 Train loss: 0.027369 Validation loss: 0.0059609
# Epoch: 122 Train loss: 0.027327 Validation loss: 0.0060578
# Epoch: 123 Train loss: 0.027286 Validation loss: 0.0061523
# Epoch: 124 Train loss: 0.027245 Validation loss: 0.0062442
# Epoch: 125 Train loss: 0.027204 Validation loss: 0.0063336
# Epoch: 126 Train loss: 0.027163 Validation loss: 0.0064202
# Epoch: 127 Train loss: 0.027122 Validation loss: 0.0065041
# Epoch: 128 Train loss: 0.027082 Validation loss: 0.0065855
# Epoch: 129 Train loss: 0.027041 Validation loss: 0.0066643
# Epoch: 130 Train loss: 0.027 Validation loss: 0.0067402
# Epoch: 131 Train loss: 0.02696 Validation loss: 0.0068133
# Epoch: 132 Train loss: 0.026919 Validation loss: 0.0068836
# Epoch: 133 Train loss: 0.026879 Validation loss: 0.0069514
# Epoch: 134 Train loss: 0.026839 Validation loss: 0.0070162
# Epoch: 135 Train loss: 0.026799 Validation loss: 0.0070787
# Epoch: 136 Train loss: 0.02676 Validation loss: 0.0071384
# Epoch: 137 Train loss: 0.02672 Validation loss: 0.0071958
# Epoch: 138 Train loss: 0.026681 Validation loss: 0.0072508
# Epoch: 139 Train loss: 0.026642 Validation loss: 0.0073035
# Epoch: 140 Train loss: 0.026603 Validation loss: 0.007354
# Epoch: 141 Train loss: 0.026564 Validation loss: 0.0074022
# Epoch: 142 Train loss: 0.026526 Validation loss: 0.0074485
# Epoch: 143 Train loss: 0.026487 Validation loss: 0.0074926
# Epoch: 144 Train loss: 0.026449 Validation loss: 0.007535
# Epoch: 145 Train loss: 0.026411 Validation loss: 0.0075751
# Epoch: 146 Train loss: 0.026373 Validation loss: 0.0076137
# Epoch: 147 Train loss: 0.026335 Validation loss: 0.0076507
# Epoch: 148 Train loss: 0.026298 Validation loss: 0.0076861
# Epoch: 149 Train loss: 0.02626 Validation loss: 0.0077196
# Epoch: 150 Train loss: 0.026223 Validation loss: 0.007752
# Epoch: 151 Train loss: 0.026186 Validation loss: 0.0077825
# Epoch: 152 Train loss: 0.026149 Validation loss: 0.0078117
# Epoch: 153 Train loss: 0.026111 Validation loss: 0.0078396
# Epoch: 154 Train loss: 0.026074 Validation loss: 0.0078663
# Epoch: 155 Train loss: 0.026037 Validation loss: 0.0078915
# Epoch: 156 Train loss: 0.026 Validation loss: 0.0079154
# Epoch: 157 Train loss: 0.025963 Validation loss: 0.007938
# Epoch: 158 Train loss: 0.025927 Validation loss: 0.0079593
# Epoch: 159 Train loss: 0.02589 Validation loss: 0.0079793
# Epoch: 160 Train loss: 0.025853 Validation loss: 0.007998
# Epoch: 161 Train loss: 0.025816 Validation loss: 0.0080154
# Epoch: 162 Train loss: 0.025779 Validation loss: 0.0080315
# Epoch: 163 Train loss: 0.025742 Validation loss: 0.0080461
# Epoch: 164 Train loss: 0.025704 Validation loss: 0.0080593
# Epoch: 165 Train loss: 0.025667 Validation loss: 0.0080712
# Epoch: 166 Train loss: 0.02563 Validation loss: 0.0080819
# Epoch: 167 Train loss: 0.025593 Validation loss: 0.0080913
# Epoch: 168 Train loss: 0.025555 Validation loss: 0.0080993
# Epoch: 169 Train loss: 0.025518 Validation loss: 0.0081058
# Epoch: 170 Train loss: 0.02548 Validation loss: 0.0081112
# Epoch: 171 Train loss: 0.025442 Validation loss: 0.0081149
# Epoch: 172 Train loss: 0.025404 Validation loss: 0.0081174
# Epoch: 173 Train loss: 0.025366 Validation loss: 0.0081186
# Epoch: 174 Train loss: 0.025328 Validation loss: 0.0081183
# Epoch: 175 Train loss: 0.025289 Validation loss: 0.0081168
# Epoch: 176 Train loss: 0.02525 Validation loss: 0.0081137
# Epoch: 177 Train loss: 0.025211 Validation loss: 0.0081092
# Epoch: 178 Train loss: 0.025172 Validation loss: 0.0081036
# Epoch: 179 Train loss: 0.025133 Validation loss: 0.0080964
# Epoch: 180 Train loss: 0.025093 Validation loss: 0.0080879
# Epoch: 181 Train loss: 0.025052 Validation loss: 0.008078
# Epoch: 182 Train loss: 0.025012 Validation loss: 0.0080666
# Epoch: 183 Train loss: 0.024971 Validation loss: 0.008054
# Epoch: 184 Train loss: 0.024929 Validation loss: 0.0080397
# Epoch: 185 Train loss: 0.024887 Validation loss: 0.0080243
# Epoch: 186 Train loss: 0.024845 Validation loss: 0.0080078
# Epoch: 187 Train loss: 0.024802 Validation loss: 0.0079897
# Epoch: 188 Train loss: 0.024758 Validation loss: 0.0079702
# Epoch: 189 Train loss: 0.024713 Validation loss: 0.007949
# Epoch: 190 Train loss: 0.024668 Validation loss: 0.0079265
# Epoch: 191 Train loss: 0.024621 Validation loss: 0.007902
# Epoch: 192 Train loss: 0.024574 Validation loss: 0.0078763
# Epoch: 193 Train loss: 0.024525 Validation loss: 0.007849
# Epoch: 194 Train loss: 0.024475 Validation loss: 0.0078198
# Epoch: 195 Train loss: 0.024424 Validation loss: 0.0077888
# Epoch: 196 Train loss: 0.02437 Validation loss: 0.0077559
# Epoch: 197 Train loss: 0.024316 Validation loss: 0.007721
# Epoch: 198 Train loss: 0.024259 Validation loss: 0.0076839
# Epoch: 199 Train loss: 0.0242 Validation loss: 0.0076445
# Epoch: 200 Train loss: 0.024138 Validation loss: 0.0076028
# Epoch: 201 Train loss: 0.024074 Validation loss: 0.0075587
# Epoch: 202 Train loss: 0.024006 Validation loss: 0.007512
# Epoch: 203 Train loss: 0.023935 Validation loss: 0.007462
# Epoch: 204 Train loss: 0.02386 Validation loss: 0.0074089
# Epoch: 205 Train loss: 0.02378 Validation loss: 0.0073524
# Epoch: 206 Train loss: 0.023695 Validation loss: 0.0072922
# Epoch: 207 Train loss: 0.023605 Validation loss: 0.0072278
# Epoch: 208 Train loss: 0.023509 Validation loss: 0.0071591
# Epoch: 209 Train loss: 0.023407 Validation loss: 0.0070853
# Epoch: 210 Train loss: 0.023297 Validation loss: 0.0070063
# Epoch: 211 Train loss: 0.02318 Validation loss: 0.0069221
# Epoch: 212 Train loss: 0.023055 Validation loss: 0.0068315
# Epoch: 213 Train loss: 0.022922 Validation loss: 0.0067349
# Epoch: 214 Train loss: 0.022782 Validation loss: 0.0066316
# Epoch: 215 Train loss: 0.022634 Validation loss: 0.0065216
# Epoch: 216 Train loss: 0.02248 Validation loss: 0.006405
# Epoch: 217 Train loss: 0.022321 Validation loss: 0.0062825
# Epoch: 218 Train loss: 0.022157 Validation loss: 0.0061554
# Epoch: 219 Train loss: 0.021989 Validation loss: 0.0060244
# Epoch: 220 Train loss: 0.021818 Validation loss: 0.0058918
# Epoch: 221 Train loss: 0.021644 Validation loss: 0.0057599
# Epoch: 222 Train loss: 0.021466 Validation loss: 0.0056305
# Epoch: 223 Train loss: 0.021284 Validation loss: 0.005506
# Epoch: 224 Train loss: 0.021096 Validation loss: 0.0053878
# Epoch: 225 Train loss: 0.020901 Validation loss: 0.0052775
# Epoch: 226 Train loss: 0.020698 Validation loss: 0.0051758
# Epoch: 227 Train loss: 0.020485 Validation loss: 0.0050828
# Epoch: 228 Train loss: 0.020263 Validation loss: 0.0049981
# Epoch: 229 Train loss: 0.020034 Validation loss: 0.0049207
# Epoch: 230 Train loss: 0.019799 Validation loss: 0.0048503
# Epoch: 231 Train loss: 0.019565 Validation loss: 0.0047855
# Epoch: 232 Train loss: 0.019336 Validation loss: 0.0047259
# Epoch: 233 Train loss: 0.019118 Validation loss: 0.004672
# Epoch: 234 Train loss: 0.018912 Validation loss: 0.004625
# Epoch: 235 Train loss: 0.018722 Validation loss: 0.0045864
# Epoch: 236 Train loss: 0.018546 Validation loss: 0.0045574
# Epoch: 237 Train loss: 0.018383 Validation loss: 0.0045388
# Epoch: 238 Train loss: 0.018232 Validation loss: 0.0045319
# Epoch: 239 Train loss: 0.018091 Validation loss: 0.0045364
# Epoch: 240 Train loss: 0.017958 Validation loss: 0.0045523
# Epoch: 241 Train loss: 0.017833 Validation loss: 0.0045781
# Epoch: 242 Train loss: 0.017739 Validation loss: 0.0045957
# Epoch: 243 Train loss: 0.020374 Validation loss: 0.0044677
# Epoch: 244 Train loss: 0.023439 Validation loss: 0.0045075
# Epoch: 245 Train loss: 0.022309 Validation loss: 0.0046505
# Epoch: 246 Train loss: 0.021802 Validation loss: 0.0048212
# Epoch: 247 Train loss: 0.021453 Validation loss: 0.0050023
# Epoch: 248 Train loss: 0.0212 Validation loss: 0.005188
# Epoch: 249 Train loss: 0.021013 Validation loss: 0.0053758
# Epoch: 250 Train loss: 0.020865 Validation loss: 0.0055653
# Epoch: 251 Train loss: 0.020744 Validation loss: 0.0057563
# Epoch: 252 Train loss: 0.020638 Validation loss: 0.0059489
# Epoch: 253 Train loss: 0.020543 Validation loss: 0.0061434
# Epoch: 254 Train loss: 0.020455 Validation loss: 0.0063399
# Epoch: 255 Train loss: 0.02037 Validation loss: 0.0065385
# Epoch: 256 Train loss: 0.020288 Validation loss: 0.0067394
# Epoch: 257 Train loss: 0.020208 Validation loss: 0.006943
# Epoch: 258 Train loss: 0.020128 Validation loss: 0.0071491
# Epoch: 259 Train loss: 0.02005 Validation loss: 0.0073577
# Epoch: 260 Train loss: 0.019972 Validation loss: 0.0075692
# Epoch: 261 Train loss: 0.019894 Validation loss: 0.0077831
# Epoch: 262 Train loss: 0.019817 Validation loss: 0.0080002
# Epoch: 263 Train loss: 0.01974 Validation loss: 0.0082198
# Epoch: 264 Train loss: 0.019664 Validation loss: 0.0084424
# Epoch: 265 Train loss: 0.019587 Validation loss: 0.0086677
# Epoch: 266 Train loss: 0.019511 Validation loss: 0.0088956
# Epoch: 267 Train loss: 0.019436 Validation loss: 0.0091265
# Epoch: 268 Train loss: 0.019361 Validation loss: 0.0093605
# Epoch: 269 Train loss: 0.019285 Validation loss: 0.0095972
# Epoch: 270 Train loss: 0.019211 Validation loss: 0.0098368
# Epoch: 271 Train loss: 0.019137 Validation loss: 0.010079
# Epoch: 272 Train loss: 0.019062 Validation loss: 0.010325
# Epoch: 273 Train loss: 0.018989 Validation loss: 0.010573
# Epoch: 274 Train loss: 0.018916 Validation loss: 0.010824
# Epoch: 275 Train loss: 0.018843 Validation loss: 0.011078
# Epoch: 276 Train loss: 0.01877 Validation loss: 0.011336
# Epoch: 277 Train loss: 0.018698 Validation loss: 0.011596
# Epoch: 278 Train loss: 0.018626 Validation loss: 0.011859
# Epoch: 279 Train loss: 0.018554 Validation loss: 0.012125
# Epoch: 280 Train loss: 0.018483 Validation loss: 0.012394
# Epoch: 281 Train loss: 0.018412 Validation loss: 0.012666
# Epoch: 282 Train loss: 0.018342 Validation loss: 0.012941
# Epoch: 283 Train loss: 0.018272 Validation loss: 0.01322
# Epoch: 284 Train loss: 0.018202 Validation loss: 0.013501
# Epoch: 285 Train loss: 0.018133 Validation loss: 0.013785
# Epoch: 286 Train loss: 0.018064 Validation loss: 0.014072
# Epoch: 287 Train loss: 0.017995 Validation loss: 0.014363
# Epoch: 288 Train loss: 0.017927 Validation loss: 0.014656
# Epoch: 289 Train loss: 0.017859 Validation loss: 0.014953
# Epoch: 290 Train loss: 0.017791 Validation loss: 0.015252
# Epoch: 291 Train loss: 0.017724 Validation loss: 0.015555
# Epoch: 292 Train loss: 0.017657 Validation loss: 0.01586
# Epoch: 293 Train loss: 0.017591 Validation loss: 0.016169
# Epoch: 294 Train loss: 0.017525 Validation loss: 0.016482
# Epoch: 295 Train loss: 0.017459 Validation loss: 0.016797
# Epoch: 296 Train loss: 0.017394 Validation loss: 0.017115
# Epoch: 297 Train loss: 0.017329 Validation loss: 0.017436
# Epoch: 298 Train loss: 0.017264 Validation loss: 0.017761
# Epoch: 299 Train loss: 0.0172 Validation loss: 0.018089
# Epoch: 300 Train loss: 0.017136 Validation loss: 0.01842
# Epoch: 301 Train loss: 0.017073 Validation loss: 0.018754
# Epoch: 302 Train loss: 0.017009 Validation loss: 0.019091
# Epoch: 303 Train loss: 0.016947 Validation loss: 0.019432
# Epoch: 304 Train loss: 0.016884 Validation loss: 0.019775
# Epoch: 305 Train loss: 0.016822 Validation loss: 0.020122
# Epoch: 306 Train loss: 0.016761 Validation loss: 0.020472
# Epoch: 307 Train loss: 0.016699 Validation loss: 0.020826
# Epoch: 308 Train loss: 0.016638 Validation loss: 0.021182
# Epoch: 309 Train loss: 0.016578 Validation loss: 0.021542
# Epoch: 310 Train loss: 0.016517 Validation loss: 0.021905
# Epoch: 311 Train loss: 0.016457 Validation loss: 0.022272
# Epoch: 312 Train loss: 0.016398 Validation loss: 0.022642
# Epoch: 313 Train loss: 0.016338 Validation loss: 0.023015
# Epoch: 314 Train loss: 0.01628 Validation loss: 0.023391
# Epoch: 315 Train loss: 0.016221 Validation loss: 0.023771
# Epoch: 316 Train loss: 0.016163 Validation loss: 0.024154
# Epoch: 317 Train loss: 0.016105 Validation loss: 0.024541
# Epoch: 318 Train loss: 0.016047 Validation loss: 0.02493
# Epoch: 319 Train loss: 0.01599 Validation loss: 0.025324
# Epoch: 320 Train loss: 0.015933 Validation loss: 0.02572
# Epoch: 321 Train loss: 0.015876 Validation loss: 0.02612
# Epoch: 322 Train loss: 0.01582 Validation loss: 0.026523
# Epoch: 323 Train loss: 0.015764 Validation loss: 0.02693
# Epoch: 324 Train loss: 0.015708 Validation loss: 0.027339
# Epoch: 325 Train loss: 0.015653 Validation loss: 0.027753
# Epoch: 326 Train loss: 0.015598 Validation loss: 0.028169
# Epoch: 327 Train loss: 0.015543 Validation loss: 0.028588
# Epoch: 328 Train loss: 0.015488 Validation loss: 0.029012
# Epoch: 329 Train loss: 0.015434 Validation loss: 0.029438
# Epoch: 330 Train loss: 0.01538 Validation loss: 0.029868
# Epoch: 331 Train loss: 0.015326 Validation loss: 0.0303
# Epoch: 332 Train loss: 0.015273 Validation loss: 0.030737
# Epoch: 333 Train loss: 0.01522 Validation loss: 0.031176
# Epoch: 334 Train loss: 0.015167 Validation loss: 0.031619
# Epoch: 335 Train loss: 0.015114 Validation loss: 0.032065
# Epoch: 336 Train loss: 0.015062 Validation loss: 0.032515
# Epoch: 337 Train loss: 0.01501 Validation loss: 0.032967
# Epoch: 338 Train loss: 0.014958 Validation loss: 0.033423
# Epoch: 339 Train loss: 0.014906 Validation loss: 0.033882
# Epoch: 340 Train loss: 0.014855 Validation loss: 0.034344
# Epoch: 341 Train loss: 0.014803 Validation loss: 0.034809
# Epoch: 342 Train loss: 0.014752 Validation loss: 0.035277
# Epoch: 343 Train loss: 0.014701 Validation loss: 0.035749
# Epoch: 344 Train loss: 0.014651 Validation loss: 0.036224
# Epoch: 345 Train loss: 0.0146 Validation loss: 0.036701
# Epoch: 346 Train loss: 0.01455 Validation loss: 0.037182
# Epoch: 347 Train loss: 0.0145 Validation loss: 0.037666
# Epoch: 348 Train loss: 0.01445 Validation loss: 0.038152
# Epoch: 349 Train loss: 0.0144 Validation loss: 0.038642
# Epoch: 350 Train loss: 0.01435 Validation loss: 0.039134
# Epoch: 351 Train loss: 0.014301 Validation loss: 0.03963
# Epoch: 352 Train loss: 0.014251 Validation loss: 0.040128
# Epoch: 353 Train loss: 0.014202 Validation loss: 0.040629
# Epoch: 354 Train loss: 0.014153 Validation loss: 0.041133
# Epoch: 355 Train loss: 0.014104 Validation loss: 0.04164
# Epoch: 356 Train loss: 0.014055 Validation loss: 0.042149
# Epoch: 357 Train loss: 0.014006 Validation loss: 0.042661
# Epoch: 358 Train loss: 0.013957 Validation loss: 0.043176
# Epoch: 359 Train loss: 0.013908 Validation loss: 0.043693
# Epoch: 360 Train loss: 0.013859 Validation loss: 0.044213
# Epoch: 361 Train loss: 0.013811 Validation loss: 0.044734
# Epoch: 362 Train loss: 0.013762 Validation loss: 0.045258
# Epoch: 363 Train loss: 0.013713 Validation loss: 0.045785
# Epoch: 364 Train loss: 0.013665 Validation loss: 0.046314
# Epoch: 365 Train loss: 0.013616 Validation loss: 0.046845
# Epoch: 366 Train loss: 0.013567 Validation loss: 0.047378
# Epoch: 367 Train loss: 0.013519 Validation loss: 0.047914
# Epoch: 368 Train loss: 0.01347 Validation loss: 0.048451
# Epoch: 369 Train loss: 0.013421 Validation loss: 0.048991
# Epoch: 370 Train loss: 0.013372 Validation loss: 0.049532
# Epoch: 371 Train loss: 0.013323 Validation loss: 0.050075
# Epoch: 372 Train loss: 0.013275 Validation loss: 0.05062
# Epoch: 373 Train loss: 0.013226 Validation loss: 0.051167
# Epoch: 374 Train loss: 0.013177 Validation loss: 0.051716
# Epoch: 375 Train loss: 0.013127 Validation loss: 0.052265
# Epoch: 376 Train loss: 0.013078 Validation loss: 0.052817
# Epoch: 377 Train loss: 0.013029 Validation loss: 0.053369
# Epoch: 378 Train loss: 0.012979 Validation loss: 0.053923
# Epoch: 379 Train loss: 0.012929 Validation loss: 0.054479
# Epoch: 380 Train loss: 0.01288 Validation loss: 0.055036
# Epoch: 381 Train loss: 0.01283 Validation loss: 0.055594
# Epoch: 382 Train loss: 0.01278 Validation loss: 0.056153
# Epoch: 383 Train loss: 0.01273 Validation loss: 0.056712
# Epoch: 384 Train loss: 0.012679 Validation loss: 0.057272
# Epoch: 385 Train loss: 0.012629 Validation loss: 0.057834
# Epoch: 386 Train loss: 0.012578 Validation loss: 0.058396
# Epoch: 387 Train loss: 0.012528 Validation loss: 0.058958
# Epoch: 388 Train loss: 0.012477 Validation loss: 0.059522
# Epoch: 389 Train loss: 0.012426 Validation loss: 0.060085
# Epoch: 390 Train loss: 0.012375 Validation loss: 0.060649
# Epoch: 391 Train loss: 0.012324 Validation loss: 0.061214
# Epoch: 392 Train loss: 0.012273 Validation loss: 0.061779
# Epoch: 393 Train loss: 0.012222 Validation loss: 0.062344
# Epoch: 394 Train loss: 0.01217 Validation loss: 0.062909
# Epoch: 395 Train loss: 0.012119 Validation loss: 0.063474
# Epoch: 396 Train loss: 0.012067 Validation loss: 0.064037
# Epoch: 397 Train loss: 0.012016 Validation loss: 0.064601
# Epoch: 398 Train loss: 0.011964 Validation loss: 0.065165
# Epoch: 399 Train loss: 0.011913 Validation loss: 0.065729
# Epoch: 400 Train loss: 0.011861 Validation loss: 0.066293
# Epoch: 401 Train loss: 0.01181 Validation loss: 0.066855
# Epoch: 402 Train loss: 0.011759 Validation loss: 0.067417
# Epoch: 403 Train loss: 0.011708 Validation loss: 0.067979
# Epoch: 404 Train loss: 0.011657 Validation loss: 0.06854
# Epoch: 405 Train loss: 0.011606 Validation loss: 0.069099
# Epoch: 406 Train loss: 0.011555 Validation loss: 0.069658
# Epoch: 407 Train loss: 0.011504 Validation loss: 0.070216
# Epoch: 408 Train loss: 0.011454 Validation loss: 0.070773
# Epoch: 409 Train loss: 0.011404 Validation loss: 0.071327
# Epoch: 410 Train loss: 0.011354 Validation loss: 0.071882
# Epoch: 411 Train loss: 0.011305 Validation loss: 0.072435
# Epoch: 412 Train loss: 0.011256 Validation loss: 0.072987
# Epoch: 413 Train loss: 0.011207 Validation loss: 0.073537
# Epoch: 414 Train loss: 0.011159 Validation loss: 0.074086
# Epoch: 415 Train loss: 0.011111 Validation loss: 0.074632
# Epoch: 416 Train loss: 0.011063 Validation loss: 0.075178
# Epoch: 417 Train loss: 0.011016 Validation loss: 0.07572
# Epoch: 418 Train loss: 0.01097 Validation loss: 0.076262
# Epoch: 419 Train loss: 0.010924 Validation loss: 0.076801
# Epoch: 420 Train loss: 0.010878 Validation loss: 0.07734
# Epoch: 421 Train loss: 0.010834 Validation loss: 0.077876
# Epoch: 422 Train loss: 0.010789 Validation loss: 0.07841
# Epoch: 423 Train loss: 0.010746 Validation loss: 0.078943
# Epoch: 424 Train loss: 0.010703 Validation loss: 0.079473
# Epoch: 425 Train loss: 0.010661 Validation loss: 0.080001
# Epoch: 426 Train loss: 0.010619 Validation loss: 0.080526
# Epoch: 427 Train loss: 0.010579 Validation loss: 0.081049
# Epoch: 428 Train loss: 0.010539 Validation loss: 0.081571
# Epoch: 429 Train loss: 0.010499 Validation loss: 0.08209
# Epoch: 430 Train loss: 0.010461 Validation loss: 0.082607
# Epoch: 431 Train loss: 0.010424 Validation loss: 0.083122
# Epoch: 432 Train loss: 0.010388 Validation loss: 0.083634
# Epoch: 433 Train loss: 0.010352 Validation loss: 0.084146
# Epoch: 434 Train loss: 0.010318 Validation loss: 0.084653
# Epoch: 435 Train loss: 0.010285 Validation loss: 0.085159
# Epoch: 436 Train loss: 0.010253 Validation loss: 0.085661
# Epoch: 437 Train loss: 0.010222 Validation loss: 0.086163
# Epoch: 438 Train loss: 0.010192 Validation loss: 0.086662
# Epoch: 439 Train loss: 0.010164 Validation loss: 0.087159
# Epoch: 440 Train loss: 0.010137 Validation loss: 0.087653
# Epoch: 441 Train loss: 0.010111 Validation loss: 0.088147
# Epoch: 442 Train loss: 0.010087 Validation loss: 0.088638
# Epoch: 443 Train loss: 0.010063 Validation loss: 0.089127
# Epoch: 444 Train loss: 0.010041 Validation loss: 0.089613
# Epoch: 445 Train loss: 0.01002 Validation loss: 0.090099
# Epoch: 446 Train loss: 0.010001 Validation loss: 0.090584
# Epoch: 447 Train loss: 0.0099816 Validation loss: 0.091066
# Epoch: 448 Train loss: 0.0099635 Validation loss: 0.091546
# Epoch: 449 Train loss: 0.0099461 Validation loss: 0.092024
# Epoch: 450 Train loss: 0.0099293 Validation loss: 0.0925
# Epoch: 451 Train loss: 0.0099129 Validation loss: 0.092973
# Epoch: 452 Train loss: 0.0098969 Validation loss: 0.093446
# Epoch: 453 Train loss: 0.0098812 Validation loss: 0.093915
# Epoch: 454 Train loss: 0.0098658 Validation loss: 0.094382
# Epoch: 455 Train loss: 0.0098506 Validation loss: 0.094846
# Epoch: 456 Train loss: 0.0098354 Validation loss: 0.095308
# Epoch: 457 Train loss: 0.0098205 Validation loss: 0.095766
# Epoch: 458 Train loss: 0.0098056 Validation loss: 0.096223
# Epoch: 459 Train loss: 0.0097909 Validation loss: 0.096677
# Epoch: 460 Train loss: 0.0097762 Validation loss: 0.097128
# Epoch: 461 Train loss: 0.0097617 Validation loss: 0.097576
# Epoch: 462 Train loss: 0.0097472 Validation loss: 0.098022
# Epoch: 463 Train loss: 0.0097328 Validation loss: 0.098464
# Epoch: 464 Train loss: 0.0097185 Validation loss: 0.098905
# Epoch: 465 Train loss: 0.0097043 Validation loss: 0.099342
# Epoch: 466 Train loss: 0.0096902 Validation loss: 0.099777
# Epoch: 467 Train loss: 0.0096761 Validation loss: 0.10021
# Epoch: 468 Train loss: 0.0096622 Validation loss: 0.10064
# Epoch: 469 Train loss: 0.0096483 Validation loss: 0.10107
# Epoch: 470 Train loss: 0.0096345 Validation loss: 0.10149
# Epoch: 471 Train loss: 0.0096207 Validation loss: 0.10191
# Epoch: 472 Train loss: 0.0096071 Validation loss: 0.10233
# Epoch: 473 Train loss: 0.0095935 Validation loss: 0.10275
# Epoch: 474 Train loss: 0.00958 Validation loss: 0.10316
# Epoch: 475 Train loss: 0.0095666 Validation loss: 0.10357
# Epoch: 476 Train loss: 0.0095533 Validation loss: 0.10398
# Epoch: 477 Train loss: 0.00954 Validation loss: 0.10438
# Epoch: 478 Train loss: 0.0095269 Validation loss: 0.10479
# Epoch: 479 Train loss: 0.0095138 Validation loss: 0.10518
# Epoch: 480 Train loss: 0.0095007 Validation loss: 0.10558
# Epoch: 481 Train loss: 0.0094878 Validation loss: 0.10598
# Epoch: 482 Train loss: 0.0094749 Validation loss: 0.10637
# Epoch: 483 Train loss: 0.0094621 Validation loss: 0.10676
# Epoch: 484 Train loss: 0.0094493 Validation loss: 0.10714
# Epoch: 485 Train loss: 0.0094367 Validation loss: 0.10753
# Epoch: 486 Train loss: 0.0094241 Validation loss: 0.10791
# Epoch: 487 Train loss: 0.0094115 Validation loss: 0.10829
# Epoch: 488 Train loss: 0.0093991 Validation loss: 0.10867
# Epoch: 489 Train loss: 0.0093867 Validation loss: 0.10904
# Epoch: 490 Train loss: 0.0093744 Validation loss: 0.10941
# Epoch: 491 Train loss: 0.0093621 Validation loss: 0.10978
# Epoch: 492 Train loss: 0.00935 Validation loss: 0.11015
# Epoch: 493 Train loss: 0.0093378 Validation loss: 0.11051
# Epoch: 494 Train loss: 0.0093258 Validation loss: 0.11087
# Epoch: 495 Train loss: 0.0093138 Validation loss: 0.11123
# Epoch: 496 Train loss: 0.0093019 Validation loss: 0.11158
# Epoch: 497 Train loss: 0.00929 Validation loss: 0.11193
# Epoch: 498 Train loss: 0.0092782 Validation loss: 0.11228
# Epoch: 499 Train loss: 0.0092665 Validation loss: 0.11263
# Epoch: 500 Train loss: 0.0092548 Validation loss: 0.11298
# Epoch: 501 Train loss: 0.0092432 Validation loss: 0.11332
# Epoch: 502 Train loss: 0.0092317 Validation loss: 0.11366
# Epoch: 503 Train loss: 0.0092202 Validation loss: 0.114
# Epoch: 504 Train loss: 0.0092088 Validation loss: 0.11433
# Epoch: 505 Train loss: 0.0091975 Validation loss: 0.11467
# Epoch: 506 Train loss: 0.0091862 Validation loss: 0.115
# Epoch: 507 Train loss: 0.009175 Validation loss: 0.11532
# Epoch: 508 Train loss: 0.0091638 Validation loss: 0.11565
# Epoch: 509 Train loss: 0.0091527 Validation loss: 0.11597
# Epoch: 510 Train loss: 0.0091416 Validation loss: 0.11629
# Epoch: 511 Train loss: 0.0091306 Validation loss: 0.11661
# Epoch: 512 Train loss: 0.0091197 Validation loss: 0.11692
# Epoch: 513 Train loss: 0.0091088 Validation loss: 0.11724
# Epoch: 514 Train loss: 0.009098 Validation loss: 0.11755
# Epoch: 515 Train loss: 0.0090872 Validation loss: 0.11785
# Epoch: 516 Train loss: 0.0090765 Validation loss: 0.11816
# Epoch: 517 Train loss: 0.0090658 Validation loss: 0.11846
# Epoch: 518 Train loss: 0.0090553 Validation loss: 0.11876
# Epoch: 519 Train loss: 0.0090447 Validation loss: 0.11906
# Epoch: 520 Train loss: 0.0090342 Validation loss: 0.11935
# Epoch: 521 Train loss: 0.0090238 Validation loss: 0.11965
# Epoch: 522 Train loss: 0.0090134 Validation loss: 0.11994
# Epoch: 523 Train loss: 0.0090031 Validation loss: 0.12023
# Epoch: 524 Train loss: 0.0089928 Validation loss: 0.12051
# Epoch: 525 Train loss: 0.0089826 Validation loss: 0.1208
# Epoch: 526 Train loss: 0.0089724 Validation loss: 0.12108
# Epoch: 527 Train loss: 0.0089623 Validation loss: 0.12136
# Epoch: 528 Train loss: 0.0089522 Validation loss: 0.12163
# Epoch: 529 Train loss: 0.0089422 Validation loss: 0.12191
# Epoch: 530 Train loss: 0.0089323 Validation loss: 0.12218
# Epoch: 531 Train loss: 0.0089224 Validation loss: 0.12245
# Epoch: 532 Train loss: 0.0089125 Validation loss: 0.12271
# Epoch: 533 Train loss: 0.0089027 Validation loss: 0.12298
# Epoch: 534 Train loss: 0.0088929 Validation loss: 0.12324
# Epoch: 535 Train loss: 0.0088832 Validation loss: 0.1235
# Epoch: 536 Train loss: 0.0088736 Validation loss: 0.12376
# Epoch: 537 Train loss: 0.008864 Validation loss: 0.12401
# Epoch: 538 Train loss: 0.0088544 Validation loss: 0.12426
# Epoch: 539 Train loss: 0.0088449 Validation loss: 0.12451
# Epoch: 540 Train loss: 0.0088354 Validation loss: 0.12476
# Epoch: 541 Train loss: 0.008826 Validation loss: 0.12501
# Epoch: 542 Train loss: 0.0088166 Validation loss: 0.12525
# Epoch: 543 Train loss: 0.0088073 Validation loss: 0.12549
# Epoch: 544 Train loss: 0.008798 Validation loss: 0.12573
# Epoch: 545 Train loss: 0.0087888 Validation loss: 0.12597
# Epoch: 546 Train loss: 0.0087796 Validation loss: 0.1262
# Epoch: 547 Train loss: 0.0087705 Validation loss: 0.12643
# Epoch: 548 Train loss: 0.0087614 Validation loss: 0.12666
# Epoch: 549 Train loss: 0.0087523 Validation loss: 0.12689
# Epoch: 550 Train loss: 0.0087433 Validation loss: 0.12711
# Epoch: 551 Train loss: 0.0087344 Validation loss: 0.12733
# Epoch: 552 Train loss: 0.0087255 Validation loss: 0.12755
# Epoch: 553 Train loss: 0.0087166 Validation loss: 0.12777
# Epoch: 554 Train loss: 0.0087078 Validation loss: 0.12799
# Epoch: 555 Train loss: 0.008699 Validation loss: 0.1282
# Epoch: 556 Train loss: 0.0086902 Validation loss: 0.12841
# Epoch: 557 Train loss: 0.0086815 Validation loss: 0.12862
# Epoch: 558 Train loss: 0.0086729 Validation loss: 0.12883
# Epoch: 559 Train loss: 0.0086643 Validation loss: 0.12903
# Epoch: 560 Train loss: 0.0086557 Validation loss: 0.12923
# Epoch: 561 Train loss: 0.0086472 Validation loss: 0.12943
# Epoch: 562 Train loss: 0.0086387 Validation loss: 0.12963
# Epoch: 563 Train loss: 0.0086303 Validation loss: 0.12982
# Epoch: 564 Train loss: 0.0086219 Validation loss: 0.13002
# Epoch: 565 Train loss: 0.0086135 Validation loss: 0.13021
# Epoch: 566 Train loss: 0.0086052 Validation loss: 0.1304
# Epoch: 567 Train loss: 0.0085969 Validation loss: 0.13058
# Epoch: 568 Train loss: 0.0085887 Validation loss: 0.13077
# Epoch: 569 Train loss: 0.0085805 Validation loss: 0.13095
# Epoch: 570 Train loss: 0.0085723 Validation loss: 0.13113
# Epoch: 571 Train loss: 0.0085642 Validation loss: 0.13131
# Epoch: 572 Train loss: 0.0085561 Validation loss: 0.13148
# Epoch: 573 Train loss: 0.0085481 Validation loss: 0.13166
# Epoch: 574 Train loss: 0.0085401 Validation loss: 0.13183
# Epoch: 575 Train loss: 0.0085321 Validation loss: 0.132
# Epoch: 576 Train loss: 0.0085242 Validation loss: 0.13217
# Epoch: 577 Train loss: 0.0085163 Validation loss: 0.13233
# Epoch: 578 Train loss: 0.0085085 Validation loss: 0.1325
# Epoch: 579 Train loss: 0.0085007 Validation loss: 0.13266
# Epoch: 580 Train loss: 0.0084929 Validation loss: 0.13282
# Epoch: 581 Train loss: 0.0084852 Validation loss: 0.13297
# Epoch: 582 Train loss: 0.0084775 Validation loss: 0.13313
# Epoch: 583 Train loss: 0.0084698 Validation loss: 0.13328
# Epoch: 584 Train loss: 0.0084622 Validation loss: 0.13343
# Epoch: 585 Train loss: 0.0084546 Validation loss: 0.13358
# Epoch: 586 Train loss: 0.0084471 Validation loss: 0.13373
# Epoch: 587 Train loss: 0.0084395 Validation loss: 0.13388
# Epoch: 588 Train loss: 0.0084321 Validation loss: 0.13402
# Epoch: 589 Train loss: 0.0084246 Validation loss: 0.13416
# Epoch: 590 Train loss: 0.0084172 Validation loss: 0.1343
# Epoch: 591 Train loss: 0.0084098 Validation loss: 0.13444
# Epoch: 592 Train loss: 0.0084025 Validation loss: 0.13458
# Epoch: 593 Train loss: 0.0083952 Validation loss: 0.13471
# Epoch: 594 Train loss: 0.0083879 Validation loss: 0.13484
# Epoch: 595 Train loss: 0.0083807 Validation loss: 0.13497
# Epoch: 596 Train loss: 0.0083735 Validation loss: 0.1351
# Epoch: 597 Train loss: 0.0083663 Validation loss: 0.13523
# Epoch: 598 Train loss: 0.0083592 Validation loss: 0.13535
# Epoch: 599 Train loss: 0.0083521 Validation loss: 0.13548
# Epoch: 600 Train loss: 0.0083451 Validation loss: 0.1356
# Epoch: 601 Train loss: 0.008338 Validation loss: 0.13572
# Epoch: 602 Train loss: 0.008331 Validation loss: 0.13583
# Epoch: 603 Train loss: 0.0083241 Validation loss: 0.13595
# Epoch: 604 Train loss: 0.0083171 Validation loss: 0.13606
# Epoch: 605 Train loss: 0.0083102 Validation loss: 0.13618
# Epoch: 606 Train loss: 0.0083034 Validation loss: 0.13629
# Epoch: 607 Train loss: 0.0082966 Validation loss: 0.13639
# Epoch: 608 Train loss: 0.0082897 Validation loss: 0.1365
# Epoch: 609 Train loss: 0.008283 Validation loss: 0.1366
# Epoch: 610 Train loss: 0.0082762 Validation loss: 0.13671
# Epoch: 611 Train loss: 0.0082695 Validation loss: 0.13681
# Epoch: 612 Train loss: 0.0082629 Validation loss: 0.13691
# Epoch: 613 Train loss: 0.0082562 Validation loss: 0.13701
# Epoch: 614 Train loss: 0.0082496 Validation loss: 0.1371
# Epoch: 615 Train loss: 0.008243 Validation loss: 0.1372
# Epoch: 616 Train loss: 0.0082365 Validation loss: 0.13729
# Epoch: 617 Train loss: 0.0082299 Validation loss: 0.13739
# Epoch: 618 Train loss: 0.0082235 Validation loss: 0.13747
# Epoch: 619 Train loss: 0.008217 Validation loss: 0.13756
# Epoch: 620 Train loss: 0.0082106 Validation loss: 0.13765
# Epoch: 621 Train loss: 0.0082042 Validation loss: 0.13773
# Epoch: 622 Train loss: 0.0081978 Validation loss: 0.13782
# Epoch: 623 Train loss: 0.0081915 Validation loss: 0.1379
# Epoch: 624 Train loss: 0.0081851 Validation loss: 0.13798
# Epoch: 625 Train loss: 0.0081789 Validation loss: 0.13805
# Epoch: 626 Train loss: 0.0081726 Validation loss: 0.13813
# Epoch: 627 Train loss: 0.0081664 Validation loss: 0.13821
# Epoch: 628 Train loss: 0.0081602 Validation loss: 0.13828
# Epoch: 629 Train loss: 0.008154 Validation loss: 0.13835
# Epoch: 630 Train loss: 0.0081479 Validation loss: 0.13842
# Epoch: 631 Train loss: 0.0081418 Validation loss: 0.13849
# Epoch: 632 Train loss: 0.0081357 Validation loss: 0.13856
# Epoch: 633 Train loss: 0.0081296 Validation loss: 0.13863
# Epoch: 634 Train loss: 0.0081236 Validation loss: 0.13869
# Epoch: 635 Train loss: 0.0081176 Validation loss: 0.13876
# Epoch: 636 Train loss: 0.0081116 Validation loss: 0.13882
# Epoch: 637 Train loss: 0.0081057 Validation loss: 0.13888
# Epoch: 638 Train loss: 0.0080997 Validation loss: 0.13894
# Epoch: 639 Train loss: 0.0080939 Validation loss: 0.139
# Epoch: 640 Train loss: 0.008088 Validation loss: 0.13906
# Epoch: 641 Train loss: 0.0080822 Validation loss: 0.13911
# Epoch: 642 Train loss: 0.0080763 Validation loss: 0.13917
# Epoch: 643 Train loss: 0.0080706 Validation loss: 0.13922
# Epoch: 644 Train loss: 0.0080648 Validation loss: 0.13927
# Epoch: 645 Train loss: 0.0080591 Validation loss: 0.13932
# Epoch: 646 Train loss: 0.0080534 Validation loss: 0.13937
# Epoch: 647 Train loss: 0.0080477 Validation loss: 0.13942
# Epoch: 648 Train loss: 0.008042 Validation loss: 0.13947
# Epoch: 649 Train loss: 0.0080364 Validation loss: 0.13951
# Epoch: 650 Train loss: 0.0080308 Validation loss: 0.13956
# Epoch: 651 Train loss: 0.0080252 Validation loss: 0.1396
# Epoch: 652 Train loss: 0.0080197 Validation loss: 0.13965
# Epoch: 653 Train loss: 0.0080141 Validation loss: 0.13969
# Epoch: 654 Train loss: 0.0080086 Validation loss: 0.13973
# Epoch: 655 Train loss: 0.0080032 Validation loss: 0.13976
# Epoch: 656 Train loss: 0.0079977 Validation loss: 0.1398
# Epoch: 657 Train loss: 0.0079923 Validation loss: 0.13984
# Epoch: 658 Train loss: 0.0079869 Validation loss: 0.13987
# Epoch: 659 Train loss: 0.0079815 Validation loss: 0.1399
# Epoch: 660 Train loss: 0.0079761 Validation loss: 0.13994
# Epoch: 661 Train loss: 0.0079708 Validation loss: 0.13996
# Epoch: 662 Train loss: 0.0079655 Validation loss: 0.13999
# Epoch: 663 Train loss: 0.0079602 Validation loss: 0.14002
# Epoch: 664 Train loss: 0.007955 Validation loss: 0.14005
# Epoch: 665 Train loss: 0.0079497 Validation loss: 0.14008
# Epoch: 666 Train loss: 0.0079445 Validation loss: 0.1401
# Epoch: 667 Train loss: 0.0079393 Validation loss: 0.14013
# Epoch: 668 Train loss: 0.0079341 Validation loss: 0.14015
# Epoch: 669 Train loss: 0.007929 Validation loss: 0.14018
# Epoch: 670 Train loss: 0.0079239 Validation loss: 0.1402
# Epoch: 671 Train loss: 0.0079188 Validation loss: 0.14022
# Epoch: 672 Train loss: 0.0079137 Validation loss: 0.14024
# Epoch: 673 Train loss: 0.0079087 Validation loss: 0.14026
# Epoch: 674 Train loss: 0.0079036 Validation loss: 0.14027
# Epoch: 675 Train loss: 0.0078986 Validation loss: 0.14029
# Epoch: 676 Train loss: 0.0078936 Validation loss: 0.1403
# Epoch: 677 Train loss: 0.0078887 Validation loss: 0.14032
# Epoch: 678 Train loss: 0.0078837 Validation loss: 0.14033
# Epoch: 679 Train loss: 0.0078788 Validation loss: 0.14035
# Epoch: 680 Train loss: 0.0078739 Validation loss: 0.14036
# Epoch: 681 Train loss: 0.007869 Validation loss: 0.14037
# Epoch: 682 Train loss: 0.0078642 Validation loss: 0.14037
# Epoch: 683 Train loss: 0.0078593 Validation loss: 0.14038
# Epoch: 684 Train loss: 0.0078545 Validation loss: 0.14039
# Epoch: 685 Train loss: 0.0078497 Validation loss: 0.1404
# Epoch: 686 Train loss: 0.007845 Validation loss: 0.1404
# Epoch: 687 Train loss: 0.0078402 Validation loss: 0.14041
# Epoch: 688 Train loss: 0.0078355 Validation loss: 0.14041
# Epoch: 689 Train loss: 0.0078308 Validation loss: 0.14041
# Epoch: 690 Train loss: 0.0078261 Validation loss: 0.14041
# Epoch: 691 Train loss: 0.0078215 Validation loss: 0.14042
# Epoch: 692 Train loss: 0.0078168 Validation loss: 0.14041
# Epoch: 693 Train loss: 0.0078122 Validation loss: 0.14041
# Epoch: 694 Train loss: 0.0078076 Validation loss: 0.14041
# Epoch: 695 Train loss: 0.007803 Validation loss: 0.14041
# Epoch: 696 Train loss: 0.0077984 Validation loss: 0.14041
# Epoch: 697 Train loss: 0.0077939 Validation loss: 0.1404
# Epoch: 698 Train loss: 0.0077894 Validation loss: 0.1404
# Epoch: 699 Train loss: 0.0077849 Validation loss: 0.14039
# Epoch: 700 Train loss: 0.0077804 Validation loss: 0.14039
# Epoch: 701 Train loss: 0.0077759 Validation loss: 0.14038
# Epoch: 702 Train loss: 0.0077715 Validation loss: 0.14037
# Epoch: 703 Train loss: 0.007767 Validation loss: 0.14036
# Epoch: 704 Train loss: 0.0077626 Validation loss: 0.14035
# Epoch: 705 Train loss: 0.0077582 Validation loss: 0.14034
# Epoch: 706 Train loss: 0.0077539 Validation loss: 0.14033
# Epoch: 707 Train loss: 0.0077495 Validation loss: 0.14032
# Epoch: 708 Train loss: 0.0077452 Validation loss: 0.1403
# Epoch: 709 Train loss: 0.0077409 Validation loss: 0.14029
# Epoch: 710 Train loss: 0.0077366 Validation loss: 0.14028
# Epoch: 711 Train loss: 0.0077323 Validation loss: 0.14026
# Epoch: 712 Train loss: 0.0077281 Validation loss: 0.14025
# Epoch: 713 Train loss: 0.0077238 Validation loss: 0.14023
# Epoch: 714 Train loss: 0.0077196 Validation loss: 0.14022
# Epoch: 715 Train loss: 0.0077154 Validation loss: 0.1402
# Epoch: 716 Train loss: 0.0077113 Validation loss: 0.14019
# Epoch: 717 Train loss: 0.0077071 Validation loss: 0.14017
# Epoch: 718 Train loss: 0.0077029 Validation loss: 0.14015
# Epoch: 719 Train loss: 0.0076988 Validation loss: 0.14013
# Epoch: 720 Train loss: 0.0076947 Validation loss: 0.14011
# Epoch: 721 Train loss: 0.0076906 Validation loss: 0.14009
# Epoch: 722 Train loss: 0.0076865 Validation loss: 0.14007
# Epoch: 723 Train loss: 0.0076825 Validation loss: 0.14005
# Epoch: 724 Train loss: 0.0076785 Validation loss: 0.14003
# Epoch: 725 Train loss: 0.0076744 Validation loss: 0.14
# Epoch: 726 Train loss: 0.0076704 Validation loss: 0.13998
# Epoch: 727 Train loss: 0.0076664 Validation loss: 0.13995
# Epoch: 728 Train loss: 0.0076625 Validation loss: 0.13993
# Epoch: 729 Train loss: 0.0076585 Validation loss: 0.1399
# Epoch: 730 Train loss: 0.0076546 Validation loss: 0.13988
# Epoch: 731 Train loss: 0.0076507 Validation loss: 0.13985
# Epoch: 732 Train loss: 0.0076468 Validation loss: 0.13982
# Epoch: 733 Train loss: 0.0076429 Validation loss: 0.1398
# Epoch: 734 Train loss: 0.007639 Validation loss: 0.13977
# Epoch: 735 Train loss: 0.0076352 Validation loss: 0.13974
# Epoch: 736 Train loss: 0.0076313 Validation loss: 0.13971
# Epoch: 737 Train loss: 0.0076275 Validation loss: 0.13968
# Epoch: 738 Train loss: 0.0076237 Validation loss: 0.13965
# Epoch: 739 Train loss: 0.0076199 Validation loss: 0.13962
# Epoch: 740 Train loss: 0.0076162 Validation loss: 0.13959
# Epoch: 741 Train loss: 0.0076124 Validation loss: 0.13955
# Epoch: 742 Train loss: 0.0076087 Validation loss: 0.13952
# Epoch: 743 Train loss: 0.0076049 Validation loss: 0.13949
# Epoch: 744 Train loss: 0.0076012 Validation loss: 0.13946
# Epoch: 745 Train loss: 0.0075975 Validation loss: 0.13942
# Epoch: 746 Train loss: 0.0075939 Validation loss: 0.13939
# Epoch: 747 Train loss: 0.0075902 Validation loss: 0.13935
# Epoch: 748 Train loss: 0.0075866 Validation loss: 0.13932
# Epoch: 749 Train loss: 0.0075829 Validation loss: 0.13928
# Epoch: 750 Train loss: 0.0075793 Validation loss: 0.13925
# Epoch: 751 Train loss: 0.0075757 Validation loss: 0.13921
# Epoch: 752 Train loss: 0.0075721 Validation loss: 0.13917
# Epoch: 753 Train loss: 0.0075686 Validation loss: 0.13914
# Epoch: 754 Train loss: 0.007565 Validation loss: 0.1391
# Epoch: 755 Train loss: 0.0075615 Validation loss: 0.13906
# Epoch: 756 Train loss: 0.007558 Validation loss: 0.13902
# Epoch: 757 Train loss: 0.0075545 Validation loss: 0.13898
# Epoch: 758 Train loss: 0.007551 Validation loss: 0.13894
# Epoch: 759 Train loss: 0.0075475 Validation loss: 0.1389
# Epoch: 760 Train loss: 0.007544 Validation loss: 0.13886
# Epoch: 761 Train loss: 0.0075406 Validation loss: 0.13882
# Epoch: 762 Train loss: 0.0075371 Validation loss: 0.13878
# Epoch: 763 Train loss: 0.0075337 Validation loss: 0.13874
# Epoch: 764 Train loss: 0.0075303 Validation loss: 0.1387
# Epoch: 765 Train loss: 0.0075269 Validation loss: 0.13866
# Epoch: 766 Train loss: 0.0075236 Validation loss: 0.13861
# Epoch: 767 Train loss: 0.0075202 Validation loss: 0.13857
# Epoch: 768 Train loss: 0.0075168 Validation loss: 0.13853
# Epoch: 769 Train loss: 0.0075135 Validation loss: 0.13849
# Epoch: 770 Train loss: 0.0075102 Validation loss: 0.13844
# Epoch: 771 Train loss: 0.0075069 Validation loss: 0.1384
# Epoch: 772 Train loss: 0.0075036 Validation loss: 0.13835
# Epoch: 773 Train loss: 0.0075003 Validation loss: 0.13831
# Epoch: 774 Train loss: 0.007497 Validation loss: 0.13826
# Epoch: 775 Train loss: 0.0074938 Validation loss: 0.13822
# Epoch: 776 Train loss: 0.0074906 Validation loss: 0.13817
# Epoch: 777 Train loss: 0.0074873 Validation loss: 0.13813
# Epoch: 778 Train loss: 0.0074841 Validation loss: 0.13808
# Epoch: 779 Train loss: 0.0074809 Validation loss: 0.13804
# Epoch: 780 Train loss: 0.0074777 Validation loss: 0.13799
# Epoch: 781 Train loss: 0.0074746 Validation loss: 0.13794
# Epoch: 782 Train loss: 0.0074714 Validation loss: 0.1379
# Epoch: 783 Train loss: 0.0074683 Validation loss: 0.13785
# Epoch: 784 Train loss: 0.0074651 Validation loss: 0.1378
# Epoch: 785 Train loss: 0.007462 Validation loss: 0.13776
# Epoch: 786 Train loss: 0.0074589 Validation loss: 0.13771
# Epoch: 787 Train loss: 0.0074558 Validation loss: 0.13766
# Epoch: 788 Train loss: 0.0074527 Validation loss: 0.13761
# Epoch: 789 Train loss: 0.0074497 Validation loss: 0.13756
# Epoch: 790 Train loss: 0.0074466 Validation loss: 0.13751
# Epoch: 791 Train loss: 0.0074436 Validation loss: 0.13746
# Epoch: 792 Train loss: 0.0074405 Validation loss: 0.13742
# Epoch: 793 Train loss: 0.0074375 Validation loss: 0.13737
# Epoch: 794 Train loss: 0.0074345 Validation loss: 0.13732
# Epoch: 795 Train loss: 0.0074315 Validation loss: 0.13727
# Epoch: 796 Train loss: 0.0074285 Validation loss: 0.13722
# Epoch: 797 Train loss: 0.0074256 Validation loss: 0.13717
# Epoch: 798 Train loss: 0.0074226 Validation loss: 0.13712
# Epoch: 799 Train loss: 0.0074197 Validation loss: 0.13706
# Epoch: 800 Train loss: 0.0074167 Validation loss: 0.13702
# Epoch: 801 Train loss: 0.0074138 Validation loss: 0.13697
# Epoch: 802 Train loss: 0.0074109 Validation loss: 0.13691
# Epoch: 803 Train loss: 0.007408 Validation loss: 0.13686
# Epoch: 804 Train loss: 0.0074051 Validation loss: 0.13681
# Epoch: 805 Train loss: 0.0074023 Validation loss: 0.13676
# Epoch: 806 Train loss: 0.0073994 Validation loss: 0.13671
# Epoch: 807 Train loss: 0.0073966 Validation loss: 0.13666
# Epoch: 808 Train loss: 0.0073937 Validation loss: 0.13661
# Epoch: 809 Train loss: 0.0073909 Validation loss: 0.13655
# Epoch: 810 Train loss: 0.0073881 Validation loss: 0.1365
# Epoch: 811 Train loss: 0.0073853 Validation loss: 0.13645
# Epoch: 812 Train loss: 0.0073825 Validation loss: 0.1364
# Epoch: 813 Train loss: 0.0073797 Validation loss: 0.13634
# Epoch: 814 Train loss: 0.0073769 Validation loss: 0.13629
# Epoch: 815 Train loss: 0.0073742 Validation loss: 0.13624
# Epoch: 816 Train loss: 0.0073714 Validation loss: 0.13618
# Epoch: 817 Train loss: 0.0073687 Validation loss: 0.13613
# Epoch: 818 Train loss: 0.007366 Validation loss: 0.13608
# Epoch: 819 Train loss: 0.0073633 Validation loss: 0.13603
# Epoch: 820 Train loss: 0.0073606 Validation loss: 0.13597
# Epoch: 821 Train loss: 0.0073579 Validation loss: 0.13592
# Epoch: 822 Train loss: 0.0073552 Validation loss: 0.13586
# Epoch: 823 Train loss: 0.0073525 Validation loss: 0.13581
# Epoch: 824 Train loss: 0.0073499 Validation loss: 0.13576
# Epoch: 825 Train loss: 0.0073472 Validation loss: 0.1357
# Epoch: 826 Train loss: 0.0073446 Validation loss: 0.13565
# Epoch: 827 Train loss: 0.007342 Validation loss: 0.13559
# Epoch: 828 Train loss: 0.0073393 Validation loss: 0.13554
# Epoch: 829 Train loss: 0.0073367 Validation loss: 0.13548
# Epoch: 830 Train loss: 0.0073341 Validation loss: 0.13543
# Epoch: 831 Train loss: 0.0073316 Validation loss: 0.13537
# Epoch: 832 Train loss: 0.007329 Validation loss: 0.13532
# Epoch: 833 Train loss: 0.0073264 Validation loss: 0.13527
# Epoch: 834 Train loss: 0.0073239 Validation loss: 0.13521
# Epoch: 835 Train loss: 0.0073213 Validation loss: 0.13516
# Epoch: 836 Train loss: 0.0073188 Validation loss: 0.1351
# Epoch: 837 Train loss: 0.0073163 Validation loss: 0.13504
# Epoch: 838 Train loss: 0.0073138 Validation loss: 0.13499
# Epoch: 839 Train loss: 0.0073113 Validation loss: 0.13493
# Epoch: 840 Train loss: 0.0073088 Validation loss: 0.13488
# Epoch: 841 Train loss: 0.0073063 Validation loss: 0.13482
# Epoch: 842 Train loss: 0.0073038 Validation loss: 0.13476
# Epoch: 843 Train loss: 0.0073013 Validation loss: 0.13471
# Epoch: 844 Train loss: 0.0072989 Validation loss: 0.13465
# Epoch: 845 Train loss: 0.0072964 Validation loss: 0.13459
# Epoch: 846 Train loss: 0.007294 Validation loss: 0.13454
# Epoch: 847 Train loss: 0.0072916 Validation loss: 0.13448
# Epoch: 848 Train loss: 0.0072892 Validation loss: 0.13442
# Epoch: 849 Train loss: 0.0072868 Validation loss: 0.13437
# Epoch: 850 Train loss: 0.0072844 Validation loss: 0.13431
# Epoch: 851 Train loss: 0.007282 Validation loss: 0.13425
# Epoch: 852 Train loss: 0.0072796 Validation loss: 0.1342
# Epoch: 853 Train loss: 0.0072773 Validation loss: 0.13414
# Epoch: 854 Train loss: 0.0072749 Validation loss: 0.13408
# Epoch: 855 Train loss: 0.0072726 Validation loss: 0.13402
# Epoch: 856 Train loss: 0.0072702 Validation loss: 0.13397
# Epoch: 857 Train loss: 0.0072679 Validation loss: 0.13391
# Epoch: 858 Train loss: 0.0072656 Validation loss: 0.13385
# Epoch: 859 Train loss: 0.0072633 Validation loss: 0.13379
# Epoch: 860 Train loss: 0.007261 Validation loss: 0.13374
# Epoch: 861 Train loss: 0.0072587 Validation loss: 0.13368
# Epoch: 862 Train loss: 0.0072564 Validation loss: 0.13362
# Epoch: 863 Train loss: 0.0072541 Validation loss: 0.13356
# Epoch: 864 Train loss: 0.0072518 Validation loss: 0.1335
# Epoch: 865 Train loss: 0.0072496 Validation loss: 0.13344
# Epoch: 866 Train loss: 0.0072473 Validation loss: 0.13339
# Epoch: 867 Train loss: 0.0072451 Validation loss: 0.13333
# Epoch: 868 Train loss: 0.0072429 Validation loss: 0.13327
# Epoch: 869 Train loss: 0.0072406 Validation loss: 0.13321
# Epoch: 870 Train loss: 0.0072384 Validation loss: 0.13316
# Epoch: 871 Train loss: 0.0072362 Validation loss: 0.1331
# Epoch: 872 Train loss: 0.007234 Validation loss: 0.13304
# Epoch: 873 Train loss: 0.0072318 Validation loss: 0.13298
# Epoch: 874 Train loss: 0.0072297 Validation loss: 0.13292
# Epoch: 875 Train loss: 0.0072275 Validation loss: 0.13286
# Epoch: 876 Train loss: 0.0072254 Validation loss: 0.13281
# Epoch: 877 Train loss: 0.0072232 Validation loss: 0.13275
# Epoch: 878 Train loss: 0.0072211 Validation loss: 0.13269
# Epoch: 879 Train loss: 0.0072189 Validation loss: 0.13263
# Epoch: 880 Train loss: 0.0072168 Validation loss: 0.13257
# Epoch: 881 Train loss: 0.0072147 Validation loss: 0.13251
# Epoch: 882 Train loss: 0.0072126 Validation loss: 0.13246
# Epoch: 883 Train loss: 0.0072105 Validation loss: 0.1324
# Epoch: 884 Train loss: 0.0072084 Validation loss: 0.13234
# Epoch: 885 Train loss: 0.0072063 Validation loss: 0.13228
# Epoch: 886 Train loss: 0.0072042 Validation loss: 0.13222
# Epoch: 887 Train loss: 0.0072021 Validation loss: 0.13216
# Epoch: 888 Train loss: 0.0072001 Validation loss: 0.1321
# Epoch: 889 Train loss: 0.007198 Validation loss: 0.13205
# Epoch: 890 Train loss: 0.007196 Validation loss: 0.13199
# Epoch: 891 Train loss: 0.0071939 Validation loss: 0.13193
# Epoch: 892 Train loss: 0.0071919 Validation loss: 0.13187
# Epoch: 893 Train loss: 0.0071899 Validation loss: 0.13182
# Epoch: 894 Train loss: 0.0071879 Validation loss: 0.13176
# Epoch: 895 Train loss: 0.0071859 Validation loss: 0.1317
# Epoch: 896 Train loss: 0.0071839 Validation loss: 0.13164
# Epoch: 897 Train loss: 0.0071819 Validation loss: 0.13158
# Epoch: 898 Train loss: 0.0071799 Validation loss: 0.13153
# Epoch: 899 Train loss: 0.0071779 Validation loss: 0.13147
# Epoch: 900 Train loss: 0.0071759 Validation loss: 0.13141
# Epoch: 901 Train loss: 0.007174 Validation loss: 0.13135
# Epoch: 902 Train loss: 0.007172 Validation loss: 0.13129
# Epoch: 903 Train loss: 0.0071701 Validation loss: 0.13123
# Epoch: 904 Train loss: 0.0071681 Validation loss: 0.13118
# Epoch: 905 Train loss: 0.0071662 Validation loss: 0.13112
# Epoch: 906 Train loss: 0.0071643 Validation loss: 0.13106
# Epoch: 907 Train loss: 0.0071624 Validation loss: 0.131
# Epoch: 908 Train loss: 0.0071605 Validation loss: 0.13094
# Epoch: 909 Train loss: 0.0071586 Validation loss: 0.13088
# Epoch: 910 Train loss: 0.0071567 Validation loss: 0.13082
# Epoch: 911 Train loss: 0.0071548 Validation loss: 0.13076
# Epoch: 912 Train loss: 0.0071529 Validation loss: 0.1307
# Epoch: 913 Train loss: 0.007151 Validation loss: 0.13065
# Epoch: 914 Train loss: 0.0071492 Validation loss: 0.13059
# Epoch: 915 Train loss: 0.0071473 Validation loss: 0.13053
# Epoch: 916 Train loss: 0.0071454 Validation loss: 0.13047
# Epoch: 917 Train loss: 0.0071436 Validation loss: 0.13041
# Epoch: 918 Train loss: 0.0071418 Validation loss: 0.13035
# Epoch: 919 Train loss: 0.0071399 Validation loss: 0.1303
# Epoch: 920 Train loss: 0.0071381 Validation loss: 0.13024
# Epoch: 921 Train loss: 0.0071363 Validation loss: 0.13018
# Epoch: 922 Train loss: 0.0071345 Validation loss: 0.13012
# Epoch: 923 Train loss: 0.0071327 Validation loss: 0.13006
# Epoch: 924 Train loss: 0.0071309 Validation loss: 0.13
# Epoch: 925 Train loss: 0.0071291 Validation loss: 0.12995
# Epoch: 926 Train loss: 0.0071273 Validation loss: 0.12989
# Epoch: 927 Train loss: 0.0071255 Validation loss: 0.12983
# Epoch: 928 Train loss: 0.0071238 Validation loss: 0.12977
# Epoch: 929 Train loss: 0.007122 Validation loss: 0.12971
# Epoch: 930 Train loss: 0.0071203 Validation loss: 0.12965
# Epoch: 931 Train loss: 0.0071185 Validation loss: 0.1296
# Epoch: 932 Train loss: 0.0071168 Validation loss: 0.12954
# Epoch: 933 Train loss: 0.007115 Validation loss: 0.12948
# Epoch: 934 Train loss: 0.0071133 Validation loss: 0.12942
# Epoch: 935 Train loss: 0.0071116 Validation loss: 0.12936
# Epoch: 936 Train loss: 0.0071099 Validation loss: 0.1293
# Epoch: 937 Train loss: 0.0071082 Validation loss: 0.12925
# Epoch: 938 Train loss: 0.0071065 Validation loss: 0.12919
# Epoch: 939 Train loss: 0.0071048 Validation loss: 0.12913
# Epoch: 940 Train loss: 0.0071031 Validation loss: 0.12907
# Epoch: 941 Train loss: 0.0071014 Validation loss: 0.12902
# Epoch: 942 Train loss: 0.0070997 Validation loss: 0.12896
# Epoch: 943 Train loss: 0.007098 Validation loss: 0.1289
# Epoch: 944 Train loss: 0.0070964 Validation loss: 0.12884
# Epoch: 945 Train loss: 0.0070947 Validation loss: 0.12878
# Epoch: 946 Train loss: 0.0070931 Validation loss: 0.12873
# Epoch: 947 Train loss: 0.0070914 Validation loss: 0.12867
# Epoch: 948 Train loss: 0.0070898 Validation loss: 0.12861
# Epoch: 949 Train loss: 0.0070881 Validation loss: 0.12855
# Epoch: 950 Train loss: 0.0070865 Validation loss: 0.1285
# Epoch: 951 Train loss: 0.0070849 Validation loss: 0.12844
# Epoch: 952 Train loss: 0.0070833 Validation loss: 0.12838
# Epoch: 953 Train loss: 0.0070817 Validation loss: 0.12832
# Epoch: 954 Train loss: 0.0070801 Validation loss: 0.12827
# Epoch: 955 Train loss: 0.0070785 Validation loss: 0.12821
# Epoch: 956 Train loss: 0.0070769 Validation loss: 0.12815
# Epoch: 957 Train loss: 0.0070753 Validation loss: 0.12809
# Epoch: 958 Train loss: 0.0070737 Validation loss: 0.12804
# Epoch: 959 Train loss: 0.0070721 Validation loss: 0.12798
# Epoch: 960 Train loss: 0.0070706 Validation loss: 0.12792
# Epoch: 961 Train loss: 0.007069 Validation loss: 0.12787
# Epoch: 962 Train loss: 0.0070674 Validation loss: 0.12781
# Epoch: 963 Train loss: 0.0070659 Validation loss: 0.12775
# Epoch: 964 Train loss: 0.0070643 Validation loss: 0.1277
# Epoch: 965 Train loss: 0.0070628 Validation loss: 0.12764
# Epoch: 966 Train loss: 0.0070613 Validation loss: 0.12758
# Epoch: 967 Train loss: 0.0070597 Validation loss: 0.12753
# Epoch: 968 Train loss: 0.0070582 Validation loss: 0.12747
# Epoch: 969 Train loss: 0.0070567 Validation loss: 0.12741
# Epoch: 970 Train loss: 0.0070552 Validation loss: 0.12736
# Epoch: 971 Train loss: 0.0070537 Validation loss: 0.1273
# Epoch: 972 Train loss: 0.0070522 Validation loss: 0.12724
# Epoch: 973 Train loss: 0.0070507 Validation loss: 0.12718
# Epoch: 974 Train loss: 0.0070492 Validation loss: 0.12713
# Epoch: 975 Train loss: 0.0070477 Validation loss: 0.12707
# Epoch: 976 Train loss: 0.0070462 Validation loss: 0.12701
# Epoch: 977 Train loss: 0.0070448 Validation loss: 0.12696
# Epoch: 978 Train loss: 0.0070433 Validation loss: 0.1269
# Epoch: 979 Train loss: 0.0070418 Validation loss: 0.12685
# Epoch: 980 Train loss: 0.0070404 Validation loss: 0.12679
# Epoch: 981 Train loss: 0.0070389 Validation loss: 0.12673
# Epoch: 982 Train loss: 0.0070375 Validation loss: 0.12668
# Epoch: 983 Train loss: 0.007036 Validation loss: 0.12662
# Epoch: 984 Train loss: 0.0070346 Validation loss: 0.12656
# Epoch: 985 Train loss: 0.0070332 Validation loss: 0.12651
# Epoch: 986 Train loss: 0.0070317 Validation loss: 0.12645
# Epoch: 987 Train loss: 0.0070303 Validation loss: 0.12639
# Epoch: 988 Train loss: 0.0070289 Validation loss: 0.12634
# Epoch: 989 Train loss: 0.0070275 Validation loss: 0.12628
# Epoch: 990 Train loss: 0.0070261 Validation loss: 0.12622
# Epoch: 991 Train loss: 0.0070247 Validation loss: 0.12617
# Epoch: 992 Train loss: 0.0070233 Validation loss: 0.12611
# Epoch: 993 Train loss: 0.0070219 Validation loss: 0.12606
# Epoch: 994 Train loss: 0.0070205 Validation loss: 0.126
# Epoch: 995 Train loss: 0.0070191 Validation loss: 0.12594
# Epoch: 996 Train loss: 0.0070178 Validation loss: 0.12588
# Epoch: 997 Train loss: 0.0070164 Validation loss: 0.12583
# Epoch: 998 Train loss: 0.007015 Validation loss: 0.12577
# Epoch: 999 Train loss: 0.0070137 Validation loss: 0.12572

# %% [markdown]
# Predicting with this model shows overfitting. For recognizing overfitting a comparison of the validation and training loss is very useful. If the training loss decreases during training while the validation loss consistently increases, the model you are training is probably overfitting. Plotting the models prediction and the target also shows that there is a significant discrepancy between the target and the prediction of the model.

# %%
y_pred = big_mdl(x)# Predict on x with "big_mdl"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Target", "Prediction", "Training samples"])
plt.show()

# %% [markdown]
# In order to implement a regularization we need to modify the loss function. Since the loss function in this exercise is computed during the training step, we define a new training step with a regularization.

# %%
""" In order to avoid overfitting we implement a training step that also includes a regularization on the weights of our big model. For this we use the Frobenius/squared l2-norm of each weight matrix/vector. 
Hint: Use the tf.reduce_sum() function on a list of individual regularization terms for each matrix/vector of the network."""

def regularized_train_step(model, optimizer, x, y, lmbd):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model(x)# Compute a prediction with "model" on the input "x"
        loss_val = tf.reduce_mean(tf.square(y-y_pred))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
        regul_val = tf.add_n([tf.reduce_sum(i*i) for i in model.trainable_variables])# Compute the regularization based on the list "model.trainable_variables"
        total_loss = loss_val + lmbd * regul_val# Add the loss with a the regularization term weighted by "lmbd"
    grads = tape.gradient(total_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# We can now set the strength of the regularization and retrain the big model with a regularization. We create another instance of the big model in order to compare the big model with and without regularization.

# %%
""" Implement the training for the bigger model with the regularized_train_step function. Note: We are plotting the MSE loss without the regularization in order to compare it with the unregularized model. """

lmbd = 0.005

big_reg_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    train_loss += regularized_train_step(big_reg_mdl,big_opt,x_t,y_t,lmbd)# Perform a regularized training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t" with the regularization parameter being "lmbd"
    train_iters += 1
    if (train_iters == N_train_samples//batch_size):# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = big_reg_mdl(x_v)# Compute a prediction with "big_mdl" on the input "x_v"
            validation_loss = tf.reduce_mean(tf.square(y_v - y_pred))# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        train_reg = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 1.1314 Validation loss: 0.03205
# Epoch: 1 Train loss: 1.1314 Validation loss: 0.031821
# Epoch: 2 Train loss: 1.1313 Validation loss: 0.031654
# Epoch: 3 Train loss: 1.1312 Validation loss: 0.031467
# Epoch: 4 Train loss: 1.131 Validation loss: 0.031237
# Epoch: 5 Train loss: 1.1307 Validation loss: 0.030932
# Epoch: 6 Train loss: 1.1303 Validation loss: 0.030485
# Epoch: 7 Train loss: 1.1293 Validation loss: 0.029675
# Epoch: 8 Train loss: 1.1248 Validation loss: 0.026956
# Epoch: 9 Train loss: 0.84487 Validation loss: 1.3408e-05
# Epoch: 10 Train loss: 0.28478 Validation loss: 0.0066245
# Epoch: 11 Train loss: 0.27907 Validation loss: 0.002686
# Epoch: 12 Train loss: 0.24044 Validation loss: 0.0018699
# Epoch: 13 Train loss: 0.19846 Validation loss: 0.0023821
# Epoch: 14 Train loss: 0.14846 Validation loss: 0.0030982
# Epoch: 15 Train loss: 0.10727 Validation loss: 0.0040167
# Epoch: 16 Train loss: 0.078892 Validation loss: 0.0051246
# Epoch: 17 Train loss: 0.06144 Validation loss: 0.0062683
# Epoch: 18 Train loss: 0.051834 Validation loss: 0.0073068
# Epoch: 19 Train loss: 0.047486 Validation loss: 0.0081021
# Epoch: 20 Train loss: 0.045766 Validation loss: 0.0086261
# Epoch: 21 Train loss: 0.044763 Validation loss: 0.0089986
# Epoch: 22 Train loss: 0.043915 Validation loss: 0.0093156
# Epoch: 23 Train loss: 0.04315 Validation loss: 0.0096074
# Epoch: 24 Train loss: 0.042455 Validation loss: 0.0098806
# Epoch: 25 Train loss: 0.041822 Validation loss: 0.010138
# Epoch: 26 Train loss: 0.041243 Validation loss: 0.010381
# Epoch: 27 Train loss: 0.04071 Validation loss: 0.010611
# Epoch: 28 Train loss: 0.040219 Validation loss: 0.01083
# Epoch: 29 Train loss: 0.039766 Validation loss: 0.011038
# Epoch: 30 Train loss: 0.039345 Validation loss: 0.011236
# Epoch: 31 Train loss: 0.038955 Validation loss: 0.011426
# Epoch: 32 Train loss: 0.038591 Validation loss: 0.011607
# Epoch: 33 Train loss: 0.038252 Validation loss: 0.011781
# Epoch: 34 Train loss: 0.037935 Validation loss: 0.011948
# Epoch: 35 Train loss: 0.037637 Validation loss: 0.012108
# Epoch: 36 Train loss: 0.037359 Validation loss: 0.012262
# Epoch: 37 Train loss: 0.037096 Validation loss: 0.012409
# Epoch: 38 Train loss: 0.03685 Validation loss: 0.012552
# Epoch: 39 Train loss: 0.036617 Validation loss: 0.012689
# Epoch: 40 Train loss: 0.036398 Validation loss: 0.012821
# Epoch: 41 Train loss: 0.03619 Validation loss: 0.012949
# Epoch: 42 Train loss: 0.035994 Validation loss: 0.013071
# Epoch: 43 Train loss: 0.035808 Validation loss: 0.01319
# Epoch: 44 Train loss: 0.035632 Validation loss: 0.013305
# Epoch: 45 Train loss: 0.035466 Validation loss: 0.013415
# Epoch: 46 Train loss: 0.035307 Validation loss: 0.013522
# Epoch: 47 Train loss: 0.035157 Validation loss: 0.013624
# Epoch: 48 Train loss: 0.035014 Validation loss: 0.013723
# Epoch: 49 Train loss: 0.034879 Validation loss: 0.013819
# Epoch: 50 Train loss: 0.03475 Validation loss: 0.01391
# Epoch: 51 Train loss: 0.034628 Validation loss: 0.013999
# Epoch: 52 Train loss: 0.034511 Validation loss: 0.014083
# Epoch: 53 Train loss: 0.034401 Validation loss: 0.014163
# Epoch: 54 Train loss: 0.034296 Validation loss: 0.01424
# Epoch: 55 Train loss: 0.034196 Validation loss: 0.014312
# Epoch: 56 Train loss: 0.034101 Validation loss: 0.014381
# Epoch: 57 Train loss: 0.034011 Validation loss: 0.014446
# Epoch: 58 Train loss: 0.033925 Validation loss: 0.014506
# Epoch: 59 Train loss: 0.033843 Validation loss: 0.014562
# Epoch: 60 Train loss: 0.033766 Validation loss: 0.014614
# Epoch: 61 Train loss: 0.033692 Validation loss: 0.014662
# Epoch: 62 Train loss: 0.033622 Validation loss: 0.014705
# Epoch: 63 Train loss: 0.033555 Validation loss: 0.014743
# Epoch: 64 Train loss: 0.033491 Validation loss: 0.014777
# Epoch: 65 Train loss: 0.033431 Validation loss: 0.014807
# Epoch: 66 Train loss: 0.033373 Validation loss: 0.014832
# Epoch: 67 Train loss: 0.033319 Validation loss: 0.014853
# Epoch: 68 Train loss: 0.033267 Validation loss: 0.01487
# Epoch: 69 Train loss: 0.033217 Validation loss: 0.014882
# Epoch: 70 Train loss: 0.03317 Validation loss: 0.014891
# Epoch: 71 Train loss: 0.033126 Validation loss: 0.014895
# Epoch: 72 Train loss: 0.033084 Validation loss: 0.014895
# Epoch: 73 Train loss: 0.033044 Validation loss: 0.014891
# Epoch: 74 Train loss: 0.033006 Validation loss: 0.014883
# Epoch: 75 Train loss: 0.03297 Validation loss: 0.014872
# Epoch: 76 Train loss: 0.032937 Validation loss: 0.014857
# Epoch: 77 Train loss: 0.032905 Validation loss: 0.014838
# Epoch: 78 Train loss: 0.032876 Validation loss: 0.014817
# Epoch: 79 Train loss: 0.032848 Validation loss: 0.014791
# Epoch: 80 Train loss: 0.032823 Validation loss: 0.014763
# Epoch: 81 Train loss: 0.0328 Validation loss: 0.014731
# Epoch: 82 Train loss: 0.032778 Validation loss: 0.014696
# Epoch: 83 Train loss: 0.032758 Validation loss: 0.014659
# Epoch: 84 Train loss: 0.032741 Validation loss: 0.014619
# Epoch: 85 Train loss: 0.032725 Validation loss: 0.014576
# Epoch: 86 Train loss: 0.032711 Validation loss: 0.01453
# Epoch: 87 Train loss: 0.032698 Validation loss: 0.014482
# Epoch: 88 Train loss: 0.032688 Validation loss: 0.014432
# Epoch: 89 Train loss: 0.032679 Validation loss: 0.014379
# Epoch: 90 Train loss: 0.032672 Validation loss: 0.014325
# Epoch: 91 Train loss: 0.032666 Validation loss: 0.014269
# Epoch: 92 Train loss: 0.032662 Validation loss: 0.014212
# Epoch: 93 Train loss: 0.03266 Validation loss: 0.014158
# Epoch: 94 Train loss: 0.03266 Validation loss: 0.014129
# Epoch: 95 Train loss: 0.032711 Validation loss: 0.014282
# Epoch: 96 Train loss: 0.034981 Validation loss: 0.015509
# Epoch: 97 Train loss: 0.04444 Validation loss: 0.015505
# Epoch: 98 Train loss: 0.037865 Validation loss: 0.014558
# Epoch: 99 Train loss: 0.034693 Validation loss: 0.014091
# Epoch: 100 Train loss: 0.034102 Validation loss: 0.013915
# Epoch: 101 Train loss: 0.034285 Validation loss: 0.013903
# Epoch: 102 Train loss: 0.034899 Validation loss: 0.013946
# Epoch: 103 Train loss: 0.035498 Validation loss: 0.013914
# Epoch: 104 Train loss: 0.035547 Validation loss: 0.013773
# Epoch: 105 Train loss: 0.035203 Validation loss: 0.0136
# Epoch: 106 Train loss: 0.034892 Validation loss: 0.013454
# Epoch: 107 Train loss: 0.034764 Validation loss: 0.013351
# Epoch: 108 Train loss: 0.034792 Validation loss: 0.013277
# Epoch: 109 Train loss: 0.034895 Validation loss: 0.013212
# Epoch: 110 Train loss: 0.034988 Validation loss: 0.013139
# Epoch: 111 Train loss: 0.035019 Validation loss: 0.013053
# Epoch: 112 Train loss: 0.034995 Validation loss: 0.012961
# Epoch: 113 Train loss: 0.034955 Validation loss: 0.012871
# Epoch: 114 Train loss: 0.03493 Validation loss: 0.012787
# Epoch: 115 Train loss: 0.034929 Validation loss: 0.01271
# Epoch: 116 Train loss: 0.034947 Validation loss: 0.012637
# Epoch: 117 Train loss: 0.034968 Validation loss: 0.012566
# Epoch: 118 Train loss: 0.034983 Validation loss: 0.012494
# Epoch: 119 Train loss: 0.034989 Validation loss: 0.012422
# Epoch: 120 Train loss: 0.034989 Validation loss: 0.01235
# Epoch: 121 Train loss: 0.034988 Validation loss: 0.012281
# Epoch: 122 Train loss: 0.034991 Validation loss: 0.012214
# Epoch: 123 Train loss: 0.034997 Validation loss: 0.012149
# Epoch: 124 Train loss: 0.035004 Validation loss: 0.012086
# Epoch: 125 Train loss: 0.035012 Validation loss: 0.012024
# Epoch: 126 Train loss: 0.035018 Validation loss: 0.011963
# Epoch: 127 Train loss: 0.035024 Validation loss: 0.011904
# Epoch: 128 Train loss: 0.035028 Validation loss: 0.011846
# Epoch: 129 Train loss: 0.035032 Validation loss: 0.01179
# Epoch: 130 Train loss: 0.035037 Validation loss: 0.011735
# Epoch: 131 Train loss: 0.035042 Validation loss: 0.011682
# Epoch: 132 Train loss: 0.035047 Validation loss: 0.01163
# Epoch: 133 Train loss: 0.035051 Validation loss: 0.011579
# Epoch: 134 Train loss: 0.035056 Validation loss: 0.01153
# Epoch: 135 Train loss: 0.03506 Validation loss: 0.011482
# Epoch: 136 Train loss: 0.035064 Validation loss: 0.011435
# Epoch: 137 Train loss: 0.035068 Validation loss: 0.01139
# Epoch: 138 Train loss: 0.035071 Validation loss: 0.011346
# Epoch: 139 Train loss: 0.035075 Validation loss: 0.011304
# Epoch: 140 Train loss: 0.035078 Validation loss: 0.011262
# Epoch: 141 Train loss: 0.035081 Validation loss: 0.011222
# Epoch: 142 Train loss: 0.035083 Validation loss: 0.011183
# Epoch: 143 Train loss: 0.035086 Validation loss: 0.011145
# Epoch: 144 Train loss: 0.035088 Validation loss: 0.011109
# Epoch: 145 Train loss: 0.03509 Validation loss: 0.011074
# Epoch: 146 Train loss: 0.035092 Validation loss: 0.011039
# Epoch: 147 Train loss: 0.035093 Validation loss: 0.011006
# Epoch: 148 Train loss: 0.035095 Validation loss: 0.010974
# Epoch: 149 Train loss: 0.035095 Validation loss: 0.010943
# Epoch: 150 Train loss: 0.035096 Validation loss: 0.010913
# Epoch: 151 Train loss: 0.035097 Validation loss: 0.010884
# Epoch: 152 Train loss: 0.035097 Validation loss: 0.010856
# Epoch: 153 Train loss: 0.035096 Validation loss: 0.010829
# Epoch: 154 Train loss: 0.035095 Validation loss: 0.010803
# Epoch: 155 Train loss: 0.035094 Validation loss: 0.010778
# Epoch: 156 Train loss: 0.035093 Validation loss: 0.010754
# Epoch: 157 Train loss: 0.035091 Validation loss: 0.010731
# Epoch: 158 Train loss: 0.035089 Validation loss: 0.010709
# Epoch: 159 Train loss: 0.035087 Validation loss: 0.010687
# Epoch: 160 Train loss: 0.035084 Validation loss: 0.010667
# Epoch: 161 Train loss: 0.035081 Validation loss: 0.010647
# Epoch: 162 Train loss: 0.035077 Validation loss: 0.010628
# Epoch: 163 Train loss: 0.035073 Validation loss: 0.01061
# Epoch: 164 Train loss: 0.035069 Validation loss: 0.010592
# Epoch: 165 Train loss: 0.035063 Validation loss: 0.010575
# Epoch: 166 Train loss: 0.035058 Validation loss: 0.010559
# Epoch: 167 Train loss: 0.035052 Validation loss: 0.010543
# Epoch: 168 Train loss: 0.035045 Validation loss: 0.010528
# Epoch: 169 Train loss: 0.035038 Validation loss: 0.010514
# Epoch: 170 Train loss: 0.035031 Validation loss: 0.0105
# Epoch: 171 Train loss: 0.035023 Validation loss: 0.010487
# Epoch: 172 Train loss: 0.035015 Validation loss: 0.010474
# Epoch: 173 Train loss: 0.035005 Validation loss: 0.010461
# Epoch: 174 Train loss: 0.034995 Validation loss: 0.01045
# Epoch: 175 Train loss: 0.034985 Validation loss: 0.010438
# Epoch: 176 Train loss: 0.034974 Validation loss: 0.010427
# Epoch: 177 Train loss: 0.034962 Validation loss: 0.010416
# Epoch: 178 Train loss: 0.03495 Validation loss: 0.010406
# Epoch: 179 Train loss: 0.034937 Validation loss: 0.010396
# Epoch: 180 Train loss: 0.034923 Validation loss: 0.010386
# Epoch: 181 Train loss: 0.034909 Validation loss: 0.010376
# Epoch: 182 Train loss: 0.034894 Validation loss: 0.010366
# Epoch: 183 Train loss: 0.034878 Validation loss: 0.010357
# Epoch: 184 Train loss: 0.034862 Validation loss: 0.010348
# Epoch: 185 Train loss: 0.034845 Validation loss: 0.010338
# Epoch: 186 Train loss: 0.034827 Validation loss: 0.010329
# Epoch: 187 Train loss: 0.034808 Validation loss: 0.010319
# Epoch: 188 Train loss: 0.034789 Validation loss: 0.01031
# Epoch: 189 Train loss: 0.03477 Validation loss: 0.0103
# Epoch: 190 Train loss: 0.03475 Validation loss: 0.010291
# Epoch: 191 Train loss: 0.03473 Validation loss: 0.010281
# Epoch: 192 Train loss: 0.034709 Validation loss: 0.010271
# Epoch: 193 Train loss: 0.034688 Validation loss: 0.01026
# Epoch: 194 Train loss: 0.034668 Validation loss: 0.010249
# Epoch: 195 Train loss: 0.034647 Validation loss: 0.010238
# Epoch: 196 Train loss: 0.034628 Validation loss: 0.010226
# Epoch: 197 Train loss: 0.034609 Validation loss: 0.010214
# Epoch: 198 Train loss: 0.034591 Validation loss: 0.010202
# Epoch: 199 Train loss: 0.034574 Validation loss: 0.010189
# Epoch: 200 Train loss: 0.03456 Validation loss: 0.010176
# Epoch: 201 Train loss: 0.034548 Validation loss: 0.010163
# Epoch: 202 Train loss: 0.034539 Validation loss: 0.01015
# Epoch: 203 Train loss: 0.034532 Validation loss: 0.010137
# Epoch: 204 Train loss: 0.034529 Validation loss: 0.010124
# Epoch: 205 Train loss: 0.03453 Validation loss: 0.010112
# Epoch: 206 Train loss: 0.034534 Validation loss: 0.0101
# Epoch: 207 Train loss: 0.034542 Validation loss: 0.01009
# Epoch: 208 Train loss: 0.034552 Validation loss: 0.01008
# Epoch: 209 Train loss: 0.034565 Validation loss: 0.010072
# Epoch: 210 Train loss: 0.034581 Validation loss: 0.010065
# Epoch: 211 Train loss: 0.034597 Validation loss: 0.01006
# Epoch: 212 Train loss: 0.034615 Validation loss: 0.010056
# Epoch: 213 Train loss: 0.034633 Validation loss: 0.010053
# Epoch: 214 Train loss: 0.034652 Validation loss: 0.010051
# Epoch: 215 Train loss: 0.034671 Validation loss: 0.010049
# Epoch: 216 Train loss: 0.03469 Validation loss: 0.010047
# Epoch: 217 Train loss: 0.034709 Validation loss: 0.010046
# Epoch: 218 Train loss: 0.034727 Validation loss: 0.010045
# Epoch: 219 Train loss: 0.034746 Validation loss: 0.010043
# Epoch: 220 Train loss: 0.034764 Validation loss: 0.010042
# Epoch: 221 Train loss: 0.034783 Validation loss: 0.010039
# Epoch: 222 Train loss: 0.034801 Validation loss: 0.010037
# Epoch: 223 Train loss: 0.034818 Validation loss: 0.010033
# Epoch: 224 Train loss: 0.034836 Validation loss: 0.010029
# Epoch: 225 Train loss: 0.034854 Validation loss: 0.010025
# Epoch: 226 Train loss: 0.034871 Validation loss: 0.01002
# Epoch: 227 Train loss: 0.034888 Validation loss: 0.010014
# Epoch: 228 Train loss: 0.034905 Validation loss: 0.010008
# Epoch: 229 Train loss: 0.034922 Validation loss: 0.010001
# Epoch: 230 Train loss: 0.034939 Validation loss: 0.0099933
# Epoch: 231 Train loss: 0.034955 Validation loss: 0.009985
# Epoch: 232 Train loss: 0.034972 Validation loss: 0.0099761
# Epoch: 233 Train loss: 0.034988 Validation loss: 0.0099664
# Epoch: 234 Train loss: 0.035004 Validation loss: 0.0099562
# Epoch: 235 Train loss: 0.03502 Validation loss: 0.0099452
# Epoch: 236 Train loss: 0.035036 Validation loss: 0.0099337
# Epoch: 237 Train loss: 0.035052 Validation loss: 0.0099215
# Epoch: 238 Train loss: 0.035067 Validation loss: 0.0099085
# Epoch: 239 Train loss: 0.035083 Validation loss: 0.0098951
# Epoch: 240 Train loss: 0.035098 Validation loss: 0.0098809
# Epoch: 241 Train loss: 0.035114 Validation loss: 0.0098662
# Epoch: 242 Train loss: 0.035129 Validation loss: 0.0098509
# Epoch: 243 Train loss: 0.035144 Validation loss: 0.009835
# Epoch: 244 Train loss: 0.035159 Validation loss: 0.0098186
# Epoch: 245 Train loss: 0.035174 Validation loss: 0.0098018
# Epoch: 246 Train loss: 0.035189 Validation loss: 0.0097844
# Epoch: 247 Train loss: 0.035204 Validation loss: 0.0097666
# Epoch: 248 Train loss: 0.035219 Validation loss: 0.0097484
# Epoch: 249 Train loss: 0.035235 Validation loss: 0.0097298
# Epoch: 250 Train loss: 0.03525 Validation loss: 0.0097109
# Epoch: 251 Train loss: 0.035265 Validation loss: 0.0096917
# Epoch: 252 Train loss: 0.03528 Validation loss: 0.0096722
# Epoch: 253 Train loss: 0.035295 Validation loss: 0.0096526
# Epoch: 254 Train loss: 0.03531 Validation loss: 0.0096327
# Epoch: 255 Train loss: 0.035325 Validation loss: 0.0096128
# Epoch: 256 Train loss: 0.035341 Validation loss: 0.0095928
# Epoch: 257 Train loss: 0.035356 Validation loss: 0.0095728
# Epoch: 258 Train loss: 0.035372 Validation loss: 0.0095528
# Epoch: 259 Train loss: 0.035387 Validation loss: 0.0095329
# Epoch: 260 Train loss: 0.035403 Validation loss: 0.0095131
# Epoch: 261 Train loss: 0.035419 Validation loss: 0.0094935
# Epoch: 262 Train loss: 0.035435 Validation loss: 0.0094741
# Epoch: 263 Train loss: 0.035451 Validation loss: 0.0094549
# Epoch: 264 Train loss: 0.035467 Validation loss: 0.009436
# Epoch: 265 Train loss: 0.035484 Validation loss: 0.0094175
# Epoch: 266 Train loss: 0.0355 Validation loss: 0.0093993
# Epoch: 267 Train loss: 0.035517 Validation loss: 0.0093815
# Epoch: 268 Train loss: 0.035534 Validation loss: 0.0093642
# Epoch: 269 Train loss: 0.035551 Validation loss: 0.0093473
# Epoch: 270 Train loss: 0.035568 Validation loss: 0.0093309
# Epoch: 271 Train loss: 0.035585 Validation loss: 0.009315
# Epoch: 272 Train loss: 0.035603 Validation loss: 0.0092996
# Epoch: 273 Train loss: 0.03562 Validation loss: 0.0092848
# Epoch: 274 Train loss: 0.035638 Validation loss: 0.0092705
# Epoch: 275 Train loss: 0.035656 Validation loss: 0.0092568
# Epoch: 276 Train loss: 0.035673 Validation loss: 0.0092437
# Epoch: 277 Train loss: 0.035691 Validation loss: 0.009231
# Epoch: 278 Train loss: 0.03571 Validation loss: 0.009219
# Epoch: 279 Train loss: 0.035728 Validation loss: 0.0092076
# Epoch: 280 Train loss: 0.035746 Validation loss: 0.0091967
# Epoch: 281 Train loss: 0.035765 Validation loss: 0.0091863
# Epoch: 282 Train loss: 0.035783 Validation loss: 0.0091765
# Epoch: 283 Train loss: 0.035802 Validation loss: 0.0091672
# Epoch: 284 Train loss: 0.03582 Validation loss: 0.0091584
# Epoch: 285 Train loss: 0.035839 Validation loss: 0.0091501
# Epoch: 286 Train loss: 0.035857 Validation loss: 0.0091423
# Epoch: 287 Train loss: 0.035876 Validation loss: 0.0091349
# Epoch: 288 Train loss: 0.035895 Validation loss: 0.0091279
# Epoch: 289 Train loss: 0.035914 Validation loss: 0.0091213
# Epoch: 290 Train loss: 0.035932 Validation loss: 0.0091151
# Epoch: 291 Train loss: 0.035951 Validation loss: 0.0091092
# Epoch: 292 Train loss: 0.03597 Validation loss: 0.0091037
# Epoch: 293 Train loss: 0.035989 Validation loss: 0.0090985
# Epoch: 294 Train loss: 0.036007 Validation loss: 0.0090935
# Epoch: 295 Train loss: 0.036026 Validation loss: 0.0090887
# Epoch: 296 Train loss: 0.036044 Validation loss: 0.0090842
# Epoch: 297 Train loss: 0.036063 Validation loss: 0.0090797
# Epoch: 298 Train loss: 0.036081 Validation loss: 0.0090755
# Epoch: 299 Train loss: 0.0361 Validation loss: 0.0090714
# Epoch: 300 Train loss: 0.036118 Validation loss: 0.0090674
# Epoch: 301 Train loss: 0.036136 Validation loss: 0.0090634
# Epoch: 302 Train loss: 0.036155 Validation loss: 0.0090595
# Epoch: 303 Train loss: 0.036173 Validation loss: 0.0090556
# Epoch: 304 Train loss: 0.036191 Validation loss: 0.0090516
# Epoch: 305 Train loss: 0.036209 Validation loss: 0.0090477
# Epoch: 306 Train loss: 0.036227 Validation loss: 0.0090437
# Epoch: 307 Train loss: 0.036244 Validation loss: 0.0090396
# Epoch: 308 Train loss: 0.036262 Validation loss: 0.0090354
# Epoch: 309 Train loss: 0.03628 Validation loss: 0.0090311
# Epoch: 310 Train loss: 0.036297 Validation loss: 0.0090266
# Epoch: 311 Train loss: 0.036315 Validation loss: 0.009022
# Epoch: 312 Train loss: 0.036332 Validation loss: 0.0090172
# Epoch: 313 Train loss: 0.036349 Validation loss: 0.0090122
# Epoch: 314 Train loss: 0.036366 Validation loss: 0.0090071
# Epoch: 315 Train loss: 0.036383 Validation loss: 0.0090017
# Epoch: 316 Train loss: 0.0364 Validation loss: 0.008996
# Epoch: 317 Train loss: 0.036417 Validation loss: 0.0089902
# Epoch: 318 Train loss: 0.036434 Validation loss: 0.008984
# Epoch: 319 Train loss: 0.03645 Validation loss: 0.0089776
# Epoch: 320 Train loss: 0.036467 Validation loss: 0.0089709
# Epoch: 321 Train loss: 0.036484 Validation loss: 0.008964
# Epoch: 322 Train loss: 0.0365 Validation loss: 0.0089567
# Epoch: 323 Train loss: 0.036516 Validation loss: 0.0089492
# Epoch: 324 Train loss: 0.036533 Validation loss: 0.0089412
# Epoch: 325 Train loss: 0.036549 Validation loss: 0.0089331
# Epoch: 326 Train loss: 0.036565 Validation loss: 0.0089246
# Epoch: 327 Train loss: 0.036581 Validation loss: 0.0089158
# Epoch: 328 Train loss: 0.036597 Validation loss: 0.0089066
# Epoch: 329 Train loss: 0.036613 Validation loss: 0.0088971
# Epoch: 330 Train loss: 0.036629 Validation loss: 0.0088872
# Epoch: 331 Train loss: 0.036644 Validation loss: 0.0088771
# Epoch: 332 Train loss: 0.03666 Validation loss: 0.0088666
# Epoch: 333 Train loss: 0.036676 Validation loss: 0.0088558
# Epoch: 334 Train loss: 0.036692 Validation loss: 0.0088445
# Epoch: 335 Train loss: 0.036707 Validation loss: 0.0088331
# Epoch: 336 Train loss: 0.036723 Validation loss: 0.0088213
# Epoch: 337 Train loss: 0.036738 Validation loss: 0.008809
# Epoch: 338 Train loss: 0.036754 Validation loss: 0.0087965
# Epoch: 339 Train loss: 0.036769 Validation loss: 0.0087836
# Epoch: 340 Train loss: 0.036784 Validation loss: 0.0087705
# Epoch: 341 Train loss: 0.0368 Validation loss: 0.0087569
# Epoch: 342 Train loss: 0.036815 Validation loss: 0.008743
# Epoch: 343 Train loss: 0.03683 Validation loss: 0.0087288
# Epoch: 344 Train loss: 0.036845 Validation loss: 0.0087143
# Epoch: 345 Train loss: 0.036861 Validation loss: 0.0086994
# Epoch: 346 Train loss: 0.036876 Validation loss: 0.0086843
# Epoch: 347 Train loss: 0.036891 Validation loss: 0.0086688
# Epoch: 348 Train loss: 0.036906 Validation loss: 0.008653
# Epoch: 349 Train loss: 0.036921 Validation loss: 0.0086369
# Epoch: 350 Train loss: 0.036936 Validation loss: 0.0086204
# Epoch: 351 Train loss: 0.036951 Validation loss: 0.0086037
# Epoch: 352 Train loss: 0.036966 Validation loss: 0.0085867
# Epoch: 353 Train loss: 0.036981 Validation loss: 0.0085694
# Epoch: 354 Train loss: 0.036996 Validation loss: 0.0085518
# Epoch: 355 Train loss: 0.037011 Validation loss: 0.0085339
# Epoch: 356 Train loss: 0.037026 Validation loss: 0.0085158
# Epoch: 357 Train loss: 0.037041 Validation loss: 0.0084973
# Epoch: 358 Train loss: 0.037056 Validation loss: 0.0084786
# Epoch: 359 Train loss: 0.037071 Validation loss: 0.0084597
# Epoch: 360 Train loss: 0.037086 Validation loss: 0.0084404
# Epoch: 361 Train loss: 0.037101 Validation loss: 0.008421
# Epoch: 362 Train loss: 0.037116 Validation loss: 0.0084012
# Epoch: 363 Train loss: 0.037131 Validation loss: 0.0083812
# Epoch: 364 Train loss: 0.037146 Validation loss: 0.0083611
# Epoch: 365 Train loss: 0.037161 Validation loss: 0.0083406
# Epoch: 366 Train loss: 0.037175 Validation loss: 0.00832
# Epoch: 367 Train loss: 0.03719 Validation loss: 0.0082991
# Epoch: 368 Train loss: 0.037205 Validation loss: 0.008278
# Epoch: 369 Train loss: 0.03722 Validation loss: 0.0082567
# Epoch: 370 Train loss: 0.037235 Validation loss: 0.0082351
# Epoch: 371 Train loss: 0.03725 Validation loss: 0.0082134
# Epoch: 372 Train loss: 0.037265 Validation loss: 0.0081915
# Epoch: 373 Train loss: 0.03728 Validation loss: 0.0081694
# Epoch: 374 Train loss: 0.037295 Validation loss: 0.0081472
# Epoch: 375 Train loss: 0.03731 Validation loss: 0.0081247
# Epoch: 376 Train loss: 0.037325 Validation loss: 0.0081021
# Epoch: 377 Train loss: 0.037339 Validation loss: 0.0080793
# Epoch: 378 Train loss: 0.037354 Validation loss: 0.0080564
# Epoch: 379 Train loss: 0.037369 Validation loss: 0.0080333
# Epoch: 380 Train loss: 0.037384 Validation loss: 0.0080101
# Epoch: 381 Train loss: 0.037399 Validation loss: 0.0079866
# Epoch: 382 Train loss: 0.037414 Validation loss: 0.0079631
# Epoch: 383 Train loss: 0.037429 Validation loss: 0.0079395
# Epoch: 384 Train loss: 0.037444 Validation loss: 0.0079157
# Epoch: 385 Train loss: 0.037459 Validation loss: 0.0078918
# Epoch: 386 Train loss: 0.037474 Validation loss: 0.0078678
# Epoch: 387 Train loss: 0.037489 Validation loss: 0.0078437
# Epoch: 388 Train loss: 0.037504 Validation loss: 0.0078195
# Epoch: 389 Train loss: 0.037519 Validation loss: 0.0077952
# Epoch: 390 Train loss: 0.037534 Validation loss: 0.0077708
# Epoch: 391 Train loss: 0.037549 Validation loss: 0.0077463
# Epoch: 392 Train loss: 0.037563 Validation loss: 0.0077217
# Epoch: 393 Train loss: 0.037578 Validation loss: 0.007697
# Epoch: 394 Train loss: 0.037593 Validation loss: 0.0076723
# Epoch: 395 Train loss: 0.037608 Validation loss: 0.0076475
# Epoch: 396 Train loss: 0.037623 Validation loss: 0.0076227
# Epoch: 397 Train loss: 0.037638 Validation loss: 0.0075977
# Epoch: 398 Train loss: 0.037653 Validation loss: 0.0075728
# Epoch: 399 Train loss: 0.037668 Validation loss: 0.0075477
# Epoch: 400 Train loss: 0.037683 Validation loss: 0.0075227
# Epoch: 401 Train loss: 0.037698 Validation loss: 0.0074976
# Epoch: 402 Train loss: 0.037713 Validation loss: 0.0074724
# Epoch: 403 Train loss: 0.037728 Validation loss: 0.0074473
# Epoch: 404 Train loss: 0.037743 Validation loss: 0.0074221
# Epoch: 405 Train loss: 0.037758 Validation loss: 0.0073968
# Epoch: 406 Train loss: 0.037773 Validation loss: 0.0073716
# Epoch: 407 Train loss: 0.037788 Validation loss: 0.0073464
# Epoch: 408 Train loss: 0.037802 Validation loss: 0.0073212
# Epoch: 409 Train loss: 0.037817 Validation loss: 0.0072959
# Epoch: 410 Train loss: 0.037832 Validation loss: 0.0072707
# Epoch: 411 Train loss: 0.037847 Validation loss: 0.0072454
# Epoch: 412 Train loss: 0.037862 Validation loss: 0.0072202
# Epoch: 413 Train loss: 0.037877 Validation loss: 0.0071949
# Epoch: 414 Train loss: 0.037892 Validation loss: 0.0071698
# Epoch: 415 Train loss: 0.037907 Validation loss: 0.0071446
# Epoch: 416 Train loss: 0.037922 Validation loss: 0.0071194
# Epoch: 417 Train loss: 0.037936 Validation loss: 0.0070943
# Epoch: 418 Train loss: 0.037951 Validation loss: 0.0070692
# Epoch: 419 Train loss: 0.037966 Validation loss: 0.0070441
# Epoch: 420 Train loss: 0.037981 Validation loss: 0.007019
# Epoch: 421 Train loss: 0.037996 Validation loss: 0.006994
# Epoch: 422 Train loss: 0.03801 Validation loss: 0.0069691
# Epoch: 423 Train loss: 0.038025 Validation loss: 0.0069442
# Epoch: 424 Train loss: 0.03804 Validation loss: 0.0069194
# Epoch: 425 Train loss: 0.038055 Validation loss: 0.0068945
# Epoch: 426 Train loss: 0.038069 Validation loss: 0.0068698
# Epoch: 427 Train loss: 0.038084 Validation loss: 0.0068451
# Epoch: 428 Train loss: 0.038099 Validation loss: 0.0068205
# Epoch: 429 Train loss: 0.038114 Validation loss: 0.0067959
# Epoch: 430 Train loss: 0.038128 Validation loss: 0.0067714
# Epoch: 431 Train loss: 0.038143 Validation loss: 0.006747
# Epoch: 432 Train loss: 0.038157 Validation loss: 0.0067227
# Epoch: 433 Train loss: 0.038172 Validation loss: 0.0066984
# Epoch: 434 Train loss: 0.038187 Validation loss: 0.0066742
# Epoch: 435 Train loss: 0.038201 Validation loss: 0.0066501
# Epoch: 436 Train loss: 0.038216 Validation loss: 0.006626
# Epoch: 437 Train loss: 0.03823 Validation loss: 0.0066021
# Epoch: 438 Train loss: 0.038245 Validation loss: 0.0065782
# Epoch: 439 Train loss: 0.038259 Validation loss: 0.0065544
# Epoch: 440 Train loss: 0.038274 Validation loss: 0.0065308
# Epoch: 441 Train loss: 0.038288 Validation loss: 0.0065072
# Epoch: 442 Train loss: 0.038303 Validation loss: 0.0064836
# Epoch: 443 Train loss: 0.038317 Validation loss: 0.0064602
# Epoch: 444 Train loss: 0.038331 Validation loss: 0.0064369
# Epoch: 445 Train loss: 0.038346 Validation loss: 0.0064137
# Epoch: 446 Train loss: 0.03836 Validation loss: 0.0063905
# Epoch: 447 Train loss: 0.038374 Validation loss: 0.0063675
# Epoch: 448 Train loss: 0.038389 Validation loss: 0.0063447
# Epoch: 449 Train loss: 0.038403 Validation loss: 0.0063219
# Epoch: 450 Train loss: 0.038417 Validation loss: 0.0062992
# Epoch: 451 Train loss: 0.038431 Validation loss: 0.0062767
# Epoch: 452 Train loss: 0.038445 Validation loss: 0.0062542
# Epoch: 453 Train loss: 0.03846 Validation loss: 0.0062318
# Epoch: 454 Train loss: 0.038474 Validation loss: 0.0062096
# Epoch: 455 Train loss: 0.038488 Validation loss: 0.0061874
# Epoch: 456 Train loss: 0.038502 Validation loss: 0.0061654
# Epoch: 457 Train loss: 0.038516 Validation loss: 0.0061434
# Epoch: 458 Train loss: 0.03853 Validation loss: 0.0061216
# Epoch: 459 Train loss: 0.038544 Validation loss: 0.0060999
# Epoch: 460 Train loss: 0.038558 Validation loss: 0.0060783
# Epoch: 461 Train loss: 0.038572 Validation loss: 0.0060568
# Epoch: 462 Train loss: 0.038586 Validation loss: 0.0060355
# Epoch: 463 Train loss: 0.0386 Validation loss: 0.0060143
# Epoch: 464 Train loss: 0.038613 Validation loss: 0.0059933
# Epoch: 465 Train loss: 0.038627 Validation loss: 0.0059723
# Epoch: 466 Train loss: 0.038641 Validation loss: 0.0059515
# Epoch: 467 Train loss: 0.038655 Validation loss: 0.0059308
# Epoch: 468 Train loss: 0.038668 Validation loss: 0.0059102
# Epoch: 469 Train loss: 0.038682 Validation loss: 0.0058897
# Epoch: 470 Train loss: 0.038696 Validation loss: 0.0058693
# Epoch: 471 Train loss: 0.038709 Validation loss: 0.0058491
# Epoch: 472 Train loss: 0.038723 Validation loss: 0.005829
# Epoch: 473 Train loss: 0.038737 Validation loss: 0.0058089
# Epoch: 474 Train loss: 0.03875 Validation loss: 0.005789
# Epoch: 475 Train loss: 0.038764 Validation loss: 0.0057693
# Epoch: 476 Train loss: 0.038777 Validation loss: 0.0057496
# Epoch: 477 Train loss: 0.03879 Validation loss: 0.0057301
# Epoch: 478 Train loss: 0.038804 Validation loss: 0.0057107
# Epoch: 479 Train loss: 0.038817 Validation loss: 0.0056915
# Epoch: 480 Train loss: 0.038831 Validation loss: 0.0056723
# Epoch: 481 Train loss: 0.038844 Validation loss: 0.0056533
# Epoch: 482 Train loss: 0.038857 Validation loss: 0.0056344
# Epoch: 483 Train loss: 0.03887 Validation loss: 0.0056156
# Epoch: 484 Train loss: 0.038884 Validation loss: 0.005597
# Epoch: 485 Train loss: 0.038897 Validation loss: 0.0055785
# Epoch: 486 Train loss: 0.03891 Validation loss: 0.0055601
# Epoch: 487 Train loss: 0.038923 Validation loss: 0.0055418
# Epoch: 488 Train loss: 0.038936 Validation loss: 0.0055237
# Epoch: 489 Train loss: 0.038949 Validation loss: 0.0055057
# Epoch: 490 Train loss: 0.038962 Validation loss: 0.0054877
# Epoch: 491 Train loss: 0.038975 Validation loss: 0.0054699
# Epoch: 492 Train loss: 0.038988 Validation loss: 0.0054522
# Epoch: 493 Train loss: 0.039001 Validation loss: 0.0054347
# Epoch: 494 Train loss: 0.039014 Validation loss: 0.0054172
# Epoch: 495 Train loss: 0.039027 Validation loss: 0.0053999
# Epoch: 496 Train loss: 0.039039 Validation loss: 0.0053827
# Epoch: 497 Train loss: 0.039052 Validation loss: 0.0053656
# Epoch: 498 Train loss: 0.039065 Validation loss: 0.0053487
# Epoch: 499 Train loss: 0.039078 Validation loss: 0.0053318
# Epoch: 500 Train loss: 0.03909 Validation loss: 0.0053151
# Epoch: 501 Train loss: 0.039103 Validation loss: 0.0052985
# Epoch: 502 Train loss: 0.039115 Validation loss: 0.0052819
# Epoch: 503 Train loss: 0.039128 Validation loss: 0.0052656
# Epoch: 504 Train loss: 0.039141 Validation loss: 0.0052493
# Epoch: 505 Train loss: 0.039153 Validation loss: 0.0052332
# Epoch: 506 Train loss: 0.039166 Validation loss: 0.0052171
# Epoch: 507 Train loss: 0.039178 Validation loss: 0.0052012
# Epoch: 508 Train loss: 0.03919 Validation loss: 0.0051853
# Epoch: 509 Train loss: 0.039203 Validation loss: 0.0051697
# Epoch: 510 Train loss: 0.039215 Validation loss: 0.005154
# Epoch: 511 Train loss: 0.039228 Validation loss: 0.0051385
# Epoch: 512 Train loss: 0.03924 Validation loss: 0.0051232
# Epoch: 513 Train loss: 0.039252 Validation loss: 0.0051079
# Epoch: 514 Train loss: 0.039264 Validation loss: 0.0050928
# Epoch: 515 Train loss: 0.039277 Validation loss: 0.0050777
# Epoch: 516 Train loss: 0.039289 Validation loss: 0.0050628
# Epoch: 517 Train loss: 0.039301 Validation loss: 0.005048
# Epoch: 518 Train loss: 0.039313 Validation loss: 0.0050332
# Epoch: 519 Train loss: 0.039325 Validation loss: 0.0050186
# Epoch: 520 Train loss: 0.039337 Validation loss: 0.0050041
# Epoch: 521 Train loss: 0.039349 Validation loss: 0.0049897
# Epoch: 522 Train loss: 0.039361 Validation loss: 0.0049754
# Epoch: 523 Train loss: 0.039373 Validation loss: 0.0049612
# Epoch: 524 Train loss: 0.039385 Validation loss: 0.0049471
# Epoch: 525 Train loss: 0.039397 Validation loss: 0.0049331
# Epoch: 526 Train loss: 0.039409 Validation loss: 0.0049193
# Epoch: 527 Train loss: 0.039421 Validation loss: 0.0049055
# Epoch: 528 Train loss: 0.039433 Validation loss: 0.0048918
# Epoch: 529 Train loss: 0.039445 Validation loss: 0.0048783
# Epoch: 530 Train loss: 0.039457 Validation loss: 0.0048649
# Epoch: 531 Train loss: 0.039469 Validation loss: 0.0048515
# Epoch: 532 Train loss: 0.039481 Validation loss: 0.0048383
# Epoch: 533 Train loss: 0.039492 Validation loss: 0.0048251
# Epoch: 534 Train loss: 0.039504 Validation loss: 0.0048121
# Epoch: 535 Train loss: 0.039516 Validation loss: 0.0047992
# Epoch: 536 Train loss: 0.039528 Validation loss: 0.0047863
# Epoch: 537 Train loss: 0.03954 Validation loss: 0.0047736
# Epoch: 538 Train loss: 0.039551 Validation loss: 0.0047611
# Epoch: 539 Train loss: 0.039563 Validation loss: 0.0047485
# Epoch: 540 Train loss: 0.039575 Validation loss: 0.0047361
# Epoch: 541 Train loss: 0.039586 Validation loss: 0.0047239
# Epoch: 542 Train loss: 0.039598 Validation loss: 0.0047117
# Epoch: 543 Train loss: 0.03961 Validation loss: 0.0046996
# Epoch: 544 Train loss: 0.039621 Validation loss: 0.0046876
# Epoch: 545 Train loss: 0.039633 Validation loss: 0.0046758
# Epoch: 546 Train loss: 0.039645 Validation loss: 0.0046641
# Epoch: 547 Train loss: 0.039656 Validation loss: 0.0046524
# Epoch: 548 Train loss: 0.039668 Validation loss: 0.0046409
# Epoch: 549 Train loss: 0.03968 Validation loss: 0.0046295
# Epoch: 550 Train loss: 0.039691 Validation loss: 0.0046182
# Epoch: 551 Train loss: 0.039703 Validation loss: 0.004607
# Epoch: 552 Train loss: 0.039714 Validation loss: 0.0045959
# Epoch: 553 Train loss: 0.039726 Validation loss: 0.0045849
# Epoch: 554 Train loss: 0.039738 Validation loss: 0.0045741
# Epoch: 555 Train loss: 0.039749 Validation loss: 0.0045633
# Epoch: 556 Train loss: 0.039761 Validation loss: 0.0045527
# Epoch: 557 Train loss: 0.039772 Validation loss: 0.0045422
# Epoch: 558 Train loss: 0.039784 Validation loss: 0.0045318
# Epoch: 559 Train loss: 0.039795 Validation loss: 0.0045216
# Epoch: 560 Train loss: 0.039807 Validation loss: 0.0045114
# Epoch: 561 Train loss: 0.039819 Validation loss: 0.0045014
# Epoch: 562 Train loss: 0.03983 Validation loss: 0.0044915
# Epoch: 563 Train loss: 0.039842 Validation loss: 0.0044817
# Epoch: 564 Train loss: 0.039853 Validation loss: 0.004472
# Epoch: 565 Train loss: 0.039865 Validation loss: 0.0044625
# Epoch: 566 Train loss: 0.039876 Validation loss: 0.0044531
# Epoch: 567 Train loss: 0.039888 Validation loss: 0.0044438
# Epoch: 568 Train loss: 0.0399 Validation loss: 0.0044346
# Epoch: 569 Train loss: 0.039911 Validation loss: 0.0044256
# Epoch: 570 Train loss: 0.039923 Validation loss: 0.0044167
# Epoch: 571 Train loss: 0.039934 Validation loss: 0.0044079
# Epoch: 572 Train loss: 0.039946 Validation loss: 0.0043992
# Epoch: 573 Train loss: 0.039957 Validation loss: 0.0043907
# Epoch: 574 Train loss: 0.039969 Validation loss: 0.0043824
# Epoch: 575 Train loss: 0.03998 Validation loss: 0.0043741
# Epoch: 576 Train loss: 0.039992 Validation loss: 0.0043659
# Epoch: 577 Train loss: 0.040003 Validation loss: 0.004358
# Epoch: 578 Train loss: 0.040015 Validation loss: 0.0043501
# Epoch: 579 Train loss: 0.040026 Validation loss: 0.0043424
# Epoch: 580 Train loss: 0.040038 Validation loss: 0.0043348
# Epoch: 581 Train loss: 0.04005 Validation loss: 0.0043273
# Epoch: 582 Train loss: 0.040061 Validation loss: 0.00432
# Epoch: 583 Train loss: 0.040073 Validation loss: 0.0043129
# Epoch: 584 Train loss: 0.040084 Validation loss: 0.0043058
# Epoch: 585 Train loss: 0.040096 Validation loss: 0.0042989
# Epoch: 586 Train loss: 0.040107 Validation loss: 0.0042922
# Epoch: 587 Train loss: 0.040119 Validation loss: 0.0042855
# Epoch: 588 Train loss: 0.04013 Validation loss: 0.0042791
# Epoch: 589 Train loss: 0.040142 Validation loss: 0.0042727
# Epoch: 590 Train loss: 0.040153 Validation loss: 0.0042666
# Epoch: 591 Train loss: 0.040164 Validation loss: 0.0042605
# Epoch: 592 Train loss: 0.040176 Validation loss: 0.0042546
# Epoch: 593 Train loss: 0.040187 Validation loss: 0.0042489
# Epoch: 594 Train loss: 0.040199 Validation loss: 0.0042432
# Epoch: 595 Train loss: 0.04021 Validation loss: 0.0042377
# Epoch: 596 Train loss: 0.040221 Validation loss: 0.0042324
# Epoch: 597 Train loss: 0.040233 Validation loss: 0.0042273
# Epoch: 598 Train loss: 0.040244 Validation loss: 0.0042222
# Epoch: 599 Train loss: 0.040256 Validation loss: 0.0042173
# Epoch: 600 Train loss: 0.040267 Validation loss: 0.0042126
# Epoch: 601 Train loss: 0.040278 Validation loss: 0.004208
# Epoch: 602 Train loss: 0.04029 Validation loss: 0.0042035
# Epoch: 603 Train loss: 0.040301 Validation loss: 0.0041992
# Epoch: 604 Train loss: 0.040312 Validation loss: 0.0041951
# Epoch: 605 Train loss: 0.040323 Validation loss: 0.004191
# Epoch: 606 Train loss: 0.040334 Validation loss: 0.0041871
# Epoch: 607 Train loss: 0.040346 Validation loss: 0.0041834
# Epoch: 608 Train loss: 0.040357 Validation loss: 0.0041799
# Epoch: 609 Train loss: 0.040368 Validation loss: 0.0041764
# Epoch: 610 Train loss: 0.040379 Validation loss: 0.0041731
# Epoch: 611 Train loss: 0.04039 Validation loss: 0.00417
# Epoch: 612 Train loss: 0.040401 Validation loss: 0.004167
# Epoch: 613 Train loss: 0.040412 Validation loss: 0.0041642
# Epoch: 614 Train loss: 0.040423 Validation loss: 0.0041615
# Epoch: 615 Train loss: 0.040434 Validation loss: 0.0041589
# Epoch: 616 Train loss: 0.040445 Validation loss: 0.0041565
# Epoch: 617 Train loss: 0.040456 Validation loss: 0.0041543
# Epoch: 618 Train loss: 0.040467 Validation loss: 0.0041521
# Epoch: 619 Train loss: 0.040478 Validation loss: 0.0041502
# Epoch: 620 Train loss: 0.040489 Validation loss: 0.0041483
# Epoch: 621 Train loss: 0.040499 Validation loss: 0.0041467
# Epoch: 622 Train loss: 0.04051 Validation loss: 0.0041452
# Epoch: 623 Train loss: 0.040521 Validation loss: 0.0041438
# Epoch: 624 Train loss: 0.040531 Validation loss: 0.0041425
# Epoch: 625 Train loss: 0.040542 Validation loss: 0.0041414
# Epoch: 626 Train loss: 0.040553 Validation loss: 0.0041405
# Epoch: 627 Train loss: 0.040563 Validation loss: 0.0041397
# Epoch: 628 Train loss: 0.040574 Validation loss: 0.004139
# Epoch: 629 Train loss: 0.040584 Validation loss: 0.0041385
# Epoch: 630 Train loss: 0.040595 Validation loss: 0.0041381
# Epoch: 631 Train loss: 0.040605 Validation loss: 0.0041378
# Epoch: 632 Train loss: 0.040615 Validation loss: 0.0041377
# Epoch: 633 Train loss: 0.040626 Validation loss: 0.0041378
# Epoch: 634 Train loss: 0.040636 Validation loss: 0.004138
# Epoch: 635 Train loss: 0.040646 Validation loss: 0.0041383
# Epoch: 636 Train loss: 0.040656 Validation loss: 0.0041388
# Epoch: 637 Train loss: 0.040666 Validation loss: 0.0041394
# Epoch: 638 Train loss: 0.040676 Validation loss: 0.0041401
# Epoch: 639 Train loss: 0.040686 Validation loss: 0.004141
# Epoch: 640 Train loss: 0.040696 Validation loss: 0.0041421
# Epoch: 641 Train loss: 0.040706 Validation loss: 0.0041432
# Epoch: 642 Train loss: 0.040716 Validation loss: 0.0041445
# Epoch: 643 Train loss: 0.040726 Validation loss: 0.004146
# Epoch: 644 Train loss: 0.040736 Validation loss: 0.0041476
# Epoch: 645 Train loss: 0.040745 Validation loss: 0.0041493
# Epoch: 646 Train loss: 0.040755 Validation loss: 0.0041511
# Epoch: 647 Train loss: 0.040765 Validation loss: 0.0041531
# Epoch: 648 Train loss: 0.040774 Validation loss: 0.0041553
# Epoch: 649 Train loss: 0.040784 Validation loss: 0.0041576
# Epoch: 650 Train loss: 0.040793 Validation loss: 0.00416
# Epoch: 651 Train loss: 0.040803 Validation loss: 0.0041625
# Epoch: 652 Train loss: 0.040812 Validation loss: 0.0041652
# Epoch: 653 Train loss: 0.040821 Validation loss: 0.004168
# Epoch: 654 Train loss: 0.040831 Validation loss: 0.0041709
# Epoch: 655 Train loss: 0.04084 Validation loss: 0.004174
# Epoch: 656 Train loss: 0.040849 Validation loss: 0.0041773
# Epoch: 657 Train loss: 0.040858 Validation loss: 0.0041806
# Epoch: 658 Train loss: 0.040867 Validation loss: 0.0041841
# Epoch: 659 Train loss: 0.040876 Validation loss: 0.0041877
# Epoch: 660 Train loss: 0.040885 Validation loss: 0.0041914
# Epoch: 661 Train loss: 0.040894 Validation loss: 0.0041953
# Epoch: 662 Train loss: 0.040903 Validation loss: 0.0041993
# Epoch: 663 Train loss: 0.040911 Validation loss: 0.0042035
# Epoch: 664 Train loss: 0.04092 Validation loss: 0.0042077
# Epoch: 665 Train loss: 0.040929 Validation loss: 0.0042121
# Epoch: 666 Train loss: 0.040937 Validation loss: 0.0042166
# Epoch: 667 Train loss: 0.040946 Validation loss: 0.0042213
# Epoch: 668 Train loss: 0.040954 Validation loss: 0.004226
# Epoch: 669 Train loss: 0.040962 Validation loss: 0.0042309
# Epoch: 670 Train loss: 0.040971 Validation loss: 0.0042359
# Epoch: 671 Train loss: 0.040979 Validation loss: 0.0042411
# Epoch: 672 Train loss: 0.040987 Validation loss: 0.0042463
# Epoch: 673 Train loss: 0.040995 Validation loss: 0.0042517
# Epoch: 674 Train loss: 0.041003 Validation loss: 0.0042572
# Epoch: 675 Train loss: 0.041011 Validation loss: 0.0042629
# Epoch: 676 Train loss: 0.041019 Validation loss: 0.0042686
# Epoch: 677 Train loss: 0.041027 Validation loss: 0.0042745
# Epoch: 678 Train loss: 0.041035 Validation loss: 0.0042805
# Epoch: 679 Train loss: 0.041043 Validation loss: 0.0042866
# Epoch: 680 Train loss: 0.04105 Validation loss: 0.0042928
# Epoch: 681 Train loss: 0.041058 Validation loss: 0.0042991
# Epoch: 682 Train loss: 0.041066 Validation loss: 0.0043056
# Epoch: 683 Train loss: 0.041073 Validation loss: 0.0043121
# Epoch: 684 Train loss: 0.04108 Validation loss: 0.0043188
# Epoch: 685 Train loss: 0.041088 Validation loss: 0.0043256
# Epoch: 686 Train loss: 0.041095 Validation loss: 0.0043325
# Epoch: 687 Train loss: 0.041102 Validation loss: 0.0043395
# Epoch: 688 Train loss: 0.041109 Validation loss: 0.0043466
# Epoch: 689 Train loss: 0.041116 Validation loss: 0.0043538
# Epoch: 690 Train loss: 0.041123 Validation loss: 0.0043612
# Epoch: 691 Train loss: 0.04113 Validation loss: 0.0043686
# Epoch: 692 Train loss: 0.041137 Validation loss: 0.0043762
# Epoch: 693 Train loss: 0.041144 Validation loss: 0.0043838
# Epoch: 694 Train loss: 0.041151 Validation loss: 0.0043915
# Epoch: 695 Train loss: 0.041158 Validation loss: 0.0043994
# Epoch: 696 Train loss: 0.041164 Validation loss: 0.0044073
# Epoch: 697 Train loss: 0.041171 Validation loss: 0.0044154
# Epoch: 698 Train loss: 0.041177 Validation loss: 0.0044235
# Epoch: 699 Train loss: 0.041184 Validation loss: 0.0044318
# Epoch: 700 Train loss: 0.04119 Validation loss: 0.0044401
# Epoch: 701 Train loss: 0.041196 Validation loss: 0.0044485
# Epoch: 702 Train loss: 0.041202 Validation loss: 0.004457
# Epoch: 703 Train loss: 0.041209 Validation loss: 0.0044657
# Epoch: 704 Train loss: 0.041215 Validation loss: 0.0044744
# Epoch: 705 Train loss: 0.041221 Validation loss: 0.0044832
# Epoch: 706 Train loss: 0.041227 Validation loss: 0.004492
# Epoch: 707 Train loss: 0.041232 Validation loss: 0.004501
# Epoch: 708 Train loss: 0.041238 Validation loss: 0.0045101
# Epoch: 709 Train loss: 0.041244 Validation loss: 0.0045192
# Epoch: 710 Train loss: 0.04125 Validation loss: 0.0045284
# Epoch: 711 Train loss: 0.041255 Validation loss: 0.0045377
# Epoch: 712 Train loss: 0.041261 Validation loss: 0.0045471
# Epoch: 713 Train loss: 0.041266 Validation loss: 0.0045566
# Epoch: 714 Train loss: 0.041272 Validation loss: 0.0045661
# Epoch: 715 Train loss: 0.041277 Validation loss: 0.0045757
# Epoch: 716 Train loss: 0.041282 Validation loss: 0.0045854
# Epoch: 717 Train loss: 0.041287 Validation loss: 0.0045952
# Epoch: 718 Train loss: 0.041293 Validation loss: 0.004605
# Epoch: 719 Train loss: 0.041298 Validation loss: 0.0046149
# Epoch: 720 Train loss: 0.041303 Validation loss: 0.0046249
# Epoch: 721 Train loss: 0.041308 Validation loss: 0.0046349
# Epoch: 722 Train loss: 0.041313 Validation loss: 0.0046451
# Epoch: 723 Train loss: 0.041317 Validation loss: 0.0046552
# Epoch: 724 Train loss: 0.041322 Validation loss: 0.0046654
# Epoch: 725 Train loss: 0.041327 Validation loss: 0.0046758
# Epoch: 726 Train loss: 0.041331 Validation loss: 0.0046861
# Epoch: 727 Train loss: 0.041336 Validation loss: 0.0046966
# Epoch: 728 Train loss: 0.041341 Validation loss: 0.004707
# Epoch: 729 Train loss: 0.041345 Validation loss: 0.0047176
# Epoch: 730 Train loss: 0.041349 Validation loss: 0.0047281
# Epoch: 731 Train loss: 0.041354 Validation loss: 0.0047388
# Epoch: 732 Train loss: 0.041358 Validation loss: 0.0047495
# Epoch: 733 Train loss: 0.041362 Validation loss: 0.0047602
# Epoch: 734 Train loss: 0.041366 Validation loss: 0.004771
# Epoch: 735 Train loss: 0.04137 Validation loss: 0.0047819
# Epoch: 736 Train loss: 0.041375 Validation loss: 0.0047928
# Epoch: 737 Train loss: 0.041378 Validation loss: 0.0048037
# Epoch: 738 Train loss: 0.041382 Validation loss: 0.0048147
# Epoch: 739 Train loss: 0.041386 Validation loss: 0.0048258
# Epoch: 740 Train loss: 0.04139 Validation loss: 0.0048368
# Epoch: 741 Train loss: 0.041394 Validation loss: 0.004848
# Epoch: 742 Train loss: 0.041398 Validation loss: 0.0048591
# Epoch: 743 Train loss: 0.041401 Validation loss: 0.0048703
# Epoch: 744 Train loss: 0.041405 Validation loss: 0.0048816
# Epoch: 745 Train loss: 0.041408 Validation loss: 0.0048929
# Epoch: 746 Train loss: 0.041412 Validation loss: 0.0049041
# Epoch: 747 Train loss: 0.041415 Validation loss: 0.0049155
# Epoch: 748 Train loss: 0.041419 Validation loss: 0.0049269
# Epoch: 749 Train loss: 0.041422 Validation loss: 0.0049383
# Epoch: 750 Train loss: 0.041425 Validation loss: 0.0049497
# Epoch: 751 Train loss: 0.041428 Validation loss: 0.0049612
# Epoch: 752 Train loss: 0.041432 Validation loss: 0.0049726
# Epoch: 753 Train loss: 0.041435 Validation loss: 0.0049842
# Epoch: 754 Train loss: 0.041438 Validation loss: 0.0049957
# Epoch: 755 Train loss: 0.041441 Validation loss: 0.0050073
# Epoch: 756 Train loss: 0.041444 Validation loss: 0.0050189
# Epoch: 757 Train loss: 0.041447 Validation loss: 0.0050305
# Epoch: 758 Train loss: 0.04145 Validation loss: 0.0050421
# Epoch: 759 Train loss: 0.041453 Validation loss: 0.0050538
# Epoch: 760 Train loss: 0.041455 Validation loss: 0.0050654
# Epoch: 761 Train loss: 0.041458 Validation loss: 0.0050771
# Epoch: 762 Train loss: 0.041461 Validation loss: 0.0050888
# Epoch: 763 Train loss: 0.041463 Validation loss: 0.0051005
# Epoch: 764 Train loss: 0.041466 Validation loss: 0.0051123
# Epoch: 765 Train loss: 0.041469 Validation loss: 0.0051241
# Epoch: 766 Train loss: 0.041471 Validation loss: 0.0051358
# Epoch: 767 Train loss: 0.041474 Validation loss: 0.0051475
# Epoch: 768 Train loss: 0.041476 Validation loss: 0.0051593
# Epoch: 769 Train loss: 0.041479 Validation loss: 0.0051711
# Epoch: 770 Train loss: 0.041481 Validation loss: 0.0051829
# Epoch: 771 Train loss: 0.041483 Validation loss: 0.0051947
# Epoch: 772 Train loss: 0.041486 Validation loss: 0.0052066
# Epoch: 773 Train loss: 0.041488 Validation loss: 0.0052184
# Epoch: 774 Train loss: 0.04149 Validation loss: 0.0052302
# Epoch: 775 Train loss: 0.041492 Validation loss: 0.005242
# Epoch: 776 Train loss: 0.041494 Validation loss: 0.0052538
# Epoch: 777 Train loss: 0.041496 Validation loss: 0.0052656
# Epoch: 778 Train loss: 0.041499 Validation loss: 0.0052775
# Epoch: 779 Train loss: 0.041501 Validation loss: 0.0052893
# Epoch: 780 Train loss: 0.041503 Validation loss: 0.0053011
# Epoch: 781 Train loss: 0.041505 Validation loss: 0.0053129
# Epoch: 782 Train loss: 0.041506 Validation loss: 0.0053247
# Epoch: 783 Train loss: 0.041508 Validation loss: 0.0053365
# Epoch: 784 Train loss: 0.04151 Validation loss: 0.0053483
# Epoch: 785 Train loss: 0.041512 Validation loss: 0.0053601
# Epoch: 786 Train loss: 0.041514 Validation loss: 0.0053718
# Epoch: 787 Train loss: 0.041516 Validation loss: 0.0053836
# Epoch: 788 Train loss: 0.041517 Validation loss: 0.0053954
# Epoch: 789 Train loss: 0.041519 Validation loss: 0.0054072
# Epoch: 790 Train loss: 0.041521 Validation loss: 0.0054189
# Epoch: 791 Train loss: 0.041522 Validation loss: 0.0054307
# Epoch: 792 Train loss: 0.041524 Validation loss: 0.0054424
# Epoch: 793 Train loss: 0.041526 Validation loss: 0.0054541
# Epoch: 794 Train loss: 0.041527 Validation loss: 0.0054658
# Epoch: 795 Train loss: 0.041529 Validation loss: 0.0054775
# Epoch: 796 Train loss: 0.04153 Validation loss: 0.0054892
# Epoch: 797 Train loss: 0.041532 Validation loss: 0.0055008
# Epoch: 798 Train loss: 0.041533 Validation loss: 0.0055125
# Epoch: 799 Train loss: 0.041535 Validation loss: 0.005524
# Epoch: 800 Train loss: 0.041536 Validation loss: 0.0055357
# Epoch: 801 Train loss: 0.041538 Validation loss: 0.0055472
# Epoch: 802 Train loss: 0.041539 Validation loss: 0.0055588
# Epoch: 803 Train loss: 0.04154 Validation loss: 0.0055703
# Epoch: 804 Train loss: 0.041542 Validation loss: 0.0055818
# Epoch: 805 Train loss: 0.041543 Validation loss: 0.0055934
# Epoch: 806 Train loss: 0.041544 Validation loss: 0.0056049
# Epoch: 807 Train loss: 0.041545 Validation loss: 0.0056164
# Epoch: 808 Train loss: 0.041547 Validation loss: 0.0056278
# Epoch: 809 Train loss: 0.041548 Validation loss: 0.0056392
# Epoch: 810 Train loss: 0.041549 Validation loss: 0.0056506
# Epoch: 811 Train loss: 0.04155 Validation loss: 0.005662
# Epoch: 812 Train loss: 0.041551 Validation loss: 0.0056733
# Epoch: 813 Train loss: 0.041552 Validation loss: 0.0056846
# Epoch: 814 Train loss: 0.041554 Validation loss: 0.005696
# Epoch: 815 Train loss: 0.041555 Validation loss: 0.0057072
# Epoch: 816 Train loss: 0.041556 Validation loss: 0.0057184
# Epoch: 817 Train loss: 0.041557 Validation loss: 0.0057297
# Epoch: 818 Train loss: 0.041558 Validation loss: 0.0057408
# Epoch: 819 Train loss: 0.041559 Validation loss: 0.005752
# Epoch: 820 Train loss: 0.04156 Validation loss: 0.0057631
# Epoch: 821 Train loss: 0.041561 Validation loss: 0.0057742
# Epoch: 822 Train loss: 0.041562 Validation loss: 0.0057853
# Epoch: 823 Train loss: 0.041563 Validation loss: 0.0057963
# Epoch: 824 Train loss: 0.041564 Validation loss: 0.0058073
# Epoch: 825 Train loss: 0.041565 Validation loss: 0.0058183
# Epoch: 826 Train loss: 0.041566 Validation loss: 0.0058292
# Epoch: 827 Train loss: 0.041566 Validation loss: 0.0058401
# Epoch: 828 Train loss: 0.041567 Validation loss: 0.005851
# Epoch: 829 Train loss: 0.041568 Validation loss: 0.0058619
# Epoch: 830 Train loss: 0.041569 Validation loss: 0.0058727
# Epoch: 831 Train loss: 0.04157 Validation loss: 0.0058835
# Epoch: 832 Train loss: 0.041571 Validation loss: 0.0058942
# Epoch: 833 Train loss: 0.041572 Validation loss: 0.0059049
# Epoch: 834 Train loss: 0.041572 Validation loss: 0.0059156
# Epoch: 835 Train loss: 0.041573 Validation loss: 0.0059263
# Epoch: 836 Train loss: 0.041574 Validation loss: 0.0059369
# Epoch: 837 Train loss: 0.041575 Validation loss: 0.0059474
# Epoch: 838 Train loss: 0.041576 Validation loss: 0.005958
# Epoch: 839 Train loss: 0.041576 Validation loss: 0.0059685
# Epoch: 840 Train loss: 0.041577 Validation loss: 0.005979
# Epoch: 841 Train loss: 0.041578 Validation loss: 0.0059894
# Epoch: 842 Train loss: 0.041578 Validation loss: 0.0059999
# Epoch: 843 Train loss: 0.041579 Validation loss: 0.0060102
# Epoch: 844 Train loss: 0.04158 Validation loss: 0.0060205
# Epoch: 845 Train loss: 0.041581 Validation loss: 0.0060307
# Epoch: 846 Train loss: 0.041581 Validation loss: 0.006041
# Epoch: 847 Train loss: 0.041582 Validation loss: 0.0060512
# Epoch: 848 Train loss: 0.041583 Validation loss: 0.0060613
# Epoch: 849 Train loss: 0.041583 Validation loss: 0.0060715
# Epoch: 850 Train loss: 0.041584 Validation loss: 0.0060815
# Epoch: 851 Train loss: 0.041585 Validation loss: 0.0060916
# Epoch: 852 Train loss: 0.041585 Validation loss: 0.0061016
# Epoch: 853 Train loss: 0.041586 Validation loss: 0.0061116
# Epoch: 854 Train loss: 0.041587 Validation loss: 0.0061215
# Epoch: 855 Train loss: 0.041587 Validation loss: 0.0061314
# Epoch: 856 Train loss: 0.041588 Validation loss: 0.0061412
# Epoch: 857 Train loss: 0.041588 Validation loss: 0.006151
# Epoch: 858 Train loss: 0.041589 Validation loss: 0.0061608
# Epoch: 859 Train loss: 0.04159 Validation loss: 0.0061705
# Epoch: 860 Train loss: 0.04159 Validation loss: 0.0061802
# Epoch: 861 Train loss: 0.041591 Validation loss: 0.0061898
# Epoch: 862 Train loss: 0.041591 Validation loss: 0.0061994
# Epoch: 863 Train loss: 0.041592 Validation loss: 0.006209
# Epoch: 864 Train loss: 0.041593 Validation loss: 0.0062185
# Epoch: 865 Train loss: 0.041593 Validation loss: 0.006228
# Epoch: 866 Train loss: 0.041594 Validation loss: 0.0062374
# Epoch: 867 Train loss: 0.041594 Validation loss: 0.0062468
# Epoch: 868 Train loss: 0.041595 Validation loss: 0.0062561
# Epoch: 869 Train loss: 0.041595 Validation loss: 0.0062654
# Epoch: 870 Train loss: 0.041596 Validation loss: 0.0062747
# Epoch: 871 Train loss: 0.041596 Validation loss: 0.0062839
# Epoch: 872 Train loss: 0.041597 Validation loss: 0.0062931
# Epoch: 873 Train loss: 0.041598 Validation loss: 0.0063022
# Epoch: 874 Train loss: 0.041598 Validation loss: 0.0063112
# Epoch: 875 Train loss: 0.041599 Validation loss: 0.0063203
# Epoch: 876 Train loss: 0.041599 Validation loss: 0.0063293
# Epoch: 877 Train loss: 0.0416 Validation loss: 0.0063382
# Epoch: 878 Train loss: 0.0416 Validation loss: 0.0063472
# Epoch: 879 Train loss: 0.041601 Validation loss: 0.006356
# Epoch: 880 Train loss: 0.041601 Validation loss: 0.0063648
# Epoch: 881 Train loss: 0.041602 Validation loss: 0.0063736
# Epoch: 882 Train loss: 0.041602 Validation loss: 0.0063823
# Epoch: 883 Train loss: 0.041603 Validation loss: 0.0063911
# Epoch: 884 Train loss: 0.041603 Validation loss: 0.0063997
# Epoch: 885 Train loss: 0.041604 Validation loss: 0.0064083
# Epoch: 886 Train loss: 0.041604 Validation loss: 0.0064168
# Epoch: 887 Train loss: 0.041605 Validation loss: 0.0064253
# Epoch: 888 Train loss: 0.041605 Validation loss: 0.0064338
# Epoch: 889 Train loss: 0.041606 Validation loss: 0.0064422
# Epoch: 890 Train loss: 0.041606 Validation loss: 0.0064506
# Epoch: 891 Train loss: 0.041607 Validation loss: 0.006459
# Epoch: 892 Train loss: 0.041608 Validation loss: 0.0064672
# Epoch: 893 Train loss: 0.041608 Validation loss: 0.0064755
# Epoch: 894 Train loss: 0.041609 Validation loss: 0.0064837
# Epoch: 895 Train loss: 0.041609 Validation loss: 0.0064918
# Epoch: 896 Train loss: 0.04161 Validation loss: 0.0064999
# Epoch: 897 Train loss: 0.04161 Validation loss: 0.006508
# Epoch: 898 Train loss: 0.041611 Validation loss: 0.006516
# Epoch: 899 Train loss: 0.041611 Validation loss: 0.006524
# Epoch: 900 Train loss: 0.041612 Validation loss: 0.0065319
# Epoch: 901 Train loss: 0.041612 Validation loss: 0.0065398
# Epoch: 902 Train loss: 0.041613 Validation loss: 0.0065476
# Epoch: 903 Train loss: 0.041613 Validation loss: 0.0065554
# Epoch: 904 Train loss: 0.041614 Validation loss: 0.0065632
# Epoch: 905 Train loss: 0.041614 Validation loss: 0.0065709
# Epoch: 906 Train loss: 0.041615 Validation loss: 0.0065786
# Epoch: 907 Train loss: 0.041615 Validation loss: 0.0065862
# Epoch: 908 Train loss: 0.041616 Validation loss: 0.0065937
# Epoch: 909 Train loss: 0.041616 Validation loss: 0.0066013
# Epoch: 910 Train loss: 0.041617 Validation loss: 0.0066087
# Epoch: 911 Train loss: 0.041617 Validation loss: 0.0066161
# Epoch: 912 Train loss: 0.041618 Validation loss: 0.0066236
# Epoch: 913 Train loss: 0.041619 Validation loss: 0.0066309
# Epoch: 914 Train loss: 0.041619 Validation loss: 0.0066382
# Epoch: 915 Train loss: 0.04162 Validation loss: 0.0066455
# Epoch: 916 Train loss: 0.04162 Validation loss: 0.0066527
# Epoch: 917 Train loss: 0.041621 Validation loss: 0.0066598
# Epoch: 918 Train loss: 0.041621 Validation loss: 0.006667
# Epoch: 919 Train loss: 0.041622 Validation loss: 0.006674
# Epoch: 920 Train loss: 0.041622 Validation loss: 0.0066811
# Epoch: 921 Train loss: 0.041623 Validation loss: 0.0066881
# Epoch: 922 Train loss: 0.041623 Validation loss: 0.006695
# Epoch: 923 Train loss: 0.041624 Validation loss: 0.0067019
# Epoch: 924 Train loss: 0.041625 Validation loss: 0.0067088
# Epoch: 925 Train loss: 0.041625 Validation loss: 0.0067156
# Epoch: 926 Train loss: 0.041626 Validation loss: 0.0067223
# Epoch: 927 Train loss: 0.041626 Validation loss: 0.0067291
# Epoch: 928 Train loss: 0.041627 Validation loss: 0.0067357
# Epoch: 929 Train loss: 0.041627 Validation loss: 0.0067423
# Epoch: 930 Train loss: 0.041628 Validation loss: 0.0067489
# Epoch: 931 Train loss: 0.041629 Validation loss: 0.0067555
# Epoch: 932 Train loss: 0.041629 Validation loss: 0.006762
# Epoch: 933 Train loss: 0.04163 Validation loss: 0.0067685
# Epoch: 934 Train loss: 0.04163 Validation loss: 0.0067748
# Epoch: 935 Train loss: 0.041631 Validation loss: 0.0067813
# Epoch: 936 Train loss: 0.041632 Validation loss: 0.0067876
# Epoch: 937 Train loss: 0.041632 Validation loss: 0.0067938
# Epoch: 938 Train loss: 0.041633 Validation loss: 0.0068001
# Epoch: 939 Train loss: 0.041633 Validation loss: 0.0068063
# Epoch: 940 Train loss: 0.041634 Validation loss: 0.0068124
# Epoch: 941 Train loss: 0.041635 Validation loss: 0.0068185
# Epoch: 942 Train loss: 0.041635 Validation loss: 0.0068246
# Epoch: 943 Train loss: 0.041636 Validation loss: 0.0068306
# Epoch: 944 Train loss: 0.041636 Validation loss: 0.0068366
# Epoch: 945 Train loss: 0.041637 Validation loss: 0.0068426
# Epoch: 946 Train loss: 0.041638 Validation loss: 0.0068484
# Epoch: 947 Train loss: 0.041638 Validation loss: 0.0068543
# Epoch: 948 Train loss: 0.041639 Validation loss: 0.0068601
# Epoch: 949 Train loss: 0.04164 Validation loss: 0.0068659
# Epoch: 950 Train loss: 0.04164 Validation loss: 0.0068716
# Epoch: 951 Train loss: 0.041641 Validation loss: 0.0068773
# Epoch: 952 Train loss: 0.041642 Validation loss: 0.0068829
# Epoch: 953 Train loss: 0.041642 Validation loss: 0.0068886
# Epoch: 954 Train loss: 0.041643 Validation loss: 0.0068941
# Epoch: 955 Train loss: 0.041644 Validation loss: 0.0068996
# Epoch: 956 Train loss: 0.041644 Validation loss: 0.0069051
# Epoch: 957 Train loss: 0.041645 Validation loss: 0.0069105
# Epoch: 958 Train loss: 0.041646 Validation loss: 0.0069159
# Epoch: 959 Train loss: 0.041646 Validation loss: 0.0069213
# Epoch: 960 Train loss: 0.041647 Validation loss: 0.0069266
# Epoch: 961 Train loss: 0.041648 Validation loss: 0.0069319
# Epoch: 962 Train loss: 0.041648 Validation loss: 0.0069371
# Epoch: 963 Train loss: 0.041649 Validation loss: 0.0069423
# Epoch: 964 Train loss: 0.04165 Validation loss: 0.0069474
# Epoch: 965 Train loss: 0.041651 Validation loss: 0.0069525
# Epoch: 966 Train loss: 0.041651 Validation loss: 0.0069576
# Epoch: 967 Train loss: 0.041652 Validation loss: 0.0069626
# Epoch: 968 Train loss: 0.041653 Validation loss: 0.0069676
# Epoch: 969 Train loss: 0.041653 Validation loss: 0.0069726
# Epoch: 970 Train loss: 0.041654 Validation loss: 0.0069774
# Epoch: 971 Train loss: 0.041655 Validation loss: 0.0069823
# Epoch: 972 Train loss: 0.041656 Validation loss: 0.0069871
# Epoch: 973 Train loss: 0.041656 Validation loss: 0.0069919
# Epoch: 974 Train loss: 0.041657 Validation loss: 0.0069967
# Epoch: 975 Train loss: 0.041658 Validation loss: 0.0070013
# Epoch: 976 Train loss: 0.041659 Validation loss: 0.007006
# Epoch: 977 Train loss: 0.041659 Validation loss: 0.0070107
# Epoch: 978 Train loss: 0.04166 Validation loss: 0.0070153
# Epoch: 979 Train loss: 0.041661 Validation loss: 0.0070198
# Epoch: 980 Train loss: 0.041662 Validation loss: 0.0070243
# Epoch: 981 Train loss: 0.041663 Validation loss: 0.0070288
# Epoch: 982 Train loss: 0.041663 Validation loss: 0.0070332
# Epoch: 983 Train loss: 0.041664 Validation loss: 0.0070376
# Epoch: 984 Train loss: 0.041665 Validation loss: 0.007042
# Epoch: 985 Train loss: 0.041666 Validation loss: 0.0070463
# Epoch: 986 Train loss: 0.041666 Validation loss: 0.0070506
# Epoch: 987 Train loss: 0.041667 Validation loss: 0.0070548
# Epoch: 988 Train loss: 0.041668 Validation loss: 0.0070591
# Epoch: 989 Train loss: 0.041669 Validation loss: 0.0070632
# Epoch: 990 Train loss: 0.04167 Validation loss: 0.0070674
# Epoch: 991 Train loss: 0.041671 Validation loss: 0.0070715
# Epoch: 992 Train loss: 0.041671 Validation loss: 0.0070755
# Epoch: 993 Train loss: 0.041672 Validation loss: 0.0070795
# Epoch: 994 Train loss: 0.041673 Validation loss: 0.0070835
# Epoch: 995 Train loss: 0.041674 Validation loss: 0.0070875
# Epoch: 996 Train loss: 0.041675 Validation loss: 0.0070914
# Epoch: 997 Train loss: 0.041676 Validation loss: 0.0070953
# Epoch: 998 Train loss: 0.041676 Validation loss: 0.0070991
# Epoch: 999 Train loss: 0.041677 Validation loss: 0.0071029

# %% [markdown]
# During the training of the regularized model we can already notice, that, although there is still a difference between training and validation loss, the validation loss decreases as the training loss dreases. The effect of the regularization becomes even more evident if we plot the predictions of the regularized model and the overfitting model.

# %%
""" We now want to plot the prediction of the regularized and unregularized big model. """

y_pred = big_reg_mdl(x)# Predict with "big_reg_mdl" on "x"
y_pred_overfit = big_mdl(x)# Predict with "reg_mdl" on "x"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.plot(x, y_pred_overfit.numpy())
plt.legend(["Target", "Regularization", "No regularization", "Training samples"])
plt.show()

# %% [markdown]
# The model with regularization seems to follow the overall trend of the data, while the model without any regularization very precisely fits the training samples. This is espacilly evident in the interval $\left[0,0.5\right]$, where the prediction of the unregularized model shows an oscillating behavior. Such oscillations are however not present in the ground truth and therefore undesirable. The regularized model on the other hand is not as flexible as the unregularized model and therefore does not fit the target function well in the interval $\left[2.25, 3.0\right]$.
#
# ## Conclusion
# In this exercise we revisited the mathematical background for a simple regression task and covered it's practical implementation in Tensorflow 2. We also explored the phenomenon of overfitting and derived different regularizations from a probabilistic perspective. This exercise covers a very simple task with a very basic neural architecture and is intended as a primer for the second part of the regression exercise, which is dealing with a bigger and more realistic problem. In this second part we will consider the problem of estimating the age of a person from a potrait picture.
